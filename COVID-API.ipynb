# %%
import requests
import pandas as pd
import json
import matplotlib.pyplot as plt
import numpy as np

# %%
response = requests.get('https://api.covid19api.com/summary')
print(response)
# Out:
# <Response [200]>

# %%
summary_string = response.content
summary = json.loads(summary_string)

# %%
summary
# Out:
# {'Message': '',
#  'Global': {'NewConfirmed': 247792,
#   'TotalConfirmed': 35144400,
#   'NewDeaths': 3764,
#   'TotalDeaths': 1036871,
#   'NewRecovered': 218056,
#   'TotalRecovered': 24500729},
#  'Countries': [{'Country': 'Afghanistan',
#    'CountryCode': 'AF',
#    'Slug': 'afghanistan',
#    'NewConfirmed': 44,
#    'TotalConfirmed': 39341,
#    'NewDeaths': 0,
#    'TotalDeaths': 1462,
#    'NewRecovered': 10,
#    'TotalRecovered': 32852,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Albania',
#    'CountryCode': 'AL',
#    'Slug': 'albania',
#    'NewConfirmed': 149,
#    'TotalConfirmed': 14266,
#    'NewDeaths': 4,
#    'TotalDeaths': 396,
#    'NewRecovered': 139,
#    'TotalRecovered': 8675,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Algeria',
#    'CountryCode': 'DZ',
#    'Slug': 'algeria',
#    'NewConfirmed': 141,
#    'TotalConfirmed': 52136,
#    'NewDeaths': 4,
#    'TotalDeaths': 1760,
#    'NewRecovered': 96,
#    'TotalRecovered': 36578,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Andorra',
#    'CountryCode': 'AD',
#    'Slug': 'andorra',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2110,
#    'NewDeaths': 0,
#    'TotalDeaths': 53,
#    'NewRecovered': 0,
#    'TotalRecovered': 1540,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Angola',
#    'CountryCode': 'AO',
#    'Slug': 'angola',
#    'NewConfirmed': 32,
#    'TotalConfirmed': 5402,
#    'NewDeaths': 2,
#    'TotalDeaths': 195,
#    'NewRecovered': 141,
#    'TotalRecovered': 2577,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Antigua and Barbuda',
#    'CountryCode': 'AG',
#    'Slug': 'antigua-and-barbuda',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 107,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 0,
#    'TotalRecovered': 96,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Argentina',
#    'CountryCode': 'AR',
#    'Slug': 'argentina',
#    'NewConfirmed': 7668,
#    'TotalConfirmed': 798486,
#    'NewDeaths': 223,
#    'TotalDeaths': 21018,
#    'NewRecovered': 10558,
#    'TotalRecovered': 636672,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Armenia',
#    'CountryCode': 'AM',
#    'Slug': 'armenia',
#    'NewConfirmed': 571,
#    'TotalConfirmed': 52496,
#    'NewDeaths': 5,
#    'TotalDeaths': 977,
#    'NewRecovered': 89,
#    'TotalRecovered': 44672,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Australia',
#    'CountryCode': 'AU',
#    'Slug': 'australia',
#    'NewConfirmed': 13,
#    'TotalConfirmed': 27148,
#    'NewDeaths': 0,
#    'TotalDeaths': 894,
#    'NewRecovered': 24,
#    'TotalRecovered': 24888,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Austria',
#    'CountryCode': 'AT',
#    'Slug': 'austria',
#    'NewConfirmed': 714,
#    'TotalConfirmed': 48146,
#    'NewDeaths': 4,
#    'TotalDeaths': 813,
#    'NewRecovered': 584,
#    'TotalRecovered': 38629,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Azerbaijan',
#    'CountryCode': 'AZ',
#    'Slug': 'azerbaijan',
#    'NewConfirmed': 130,
#    'TotalConfirmed': 40691,
#    'NewDeaths': 1,
#    'TotalDeaths': 596,
#    'NewRecovered': 142,
#    'TotalRecovered': 38496,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Bahamas',
#    'CountryCode': 'BS',
#    'Slug': 'bahamas',
#    'NewConfirmed': 77,
#    'TotalConfirmed': 4409,
#    'NewDeaths': 0,
#    'TotalDeaths': 96,
#    'NewRecovered': 0,
#    'TotalRecovered': 2375,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Bahrain',
#    'CountryCode': 'BH',
#    'Slug': 'bahrain',
#    'NewConfirmed': 352,
#    'TotalConfirmed': 72662,
#    'NewDeaths': 2,
#    'TotalDeaths': 260,
#    'NewRecovered': 662,
#    'TotalRecovered': 67475,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Bangladesh',
#    'CountryCode': 'BD',
#    'Slug': 'bangladesh',
#    'NewConfirmed': 1125,
#    'TotalConfirmed': 368690,
#    'NewDeaths': 23,
#    'TotalDeaths': 5348,
#    'NewRecovered': 1587,
#    'TotalRecovered': 281656,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Barbados',
#    'CountryCode': 'BB',
#    'Slug': 'barbados',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 199,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 0,
#    'TotalRecovered': 182,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Belarus',
#    'CountryCode': 'BY',
#    'Slug': 'belarus',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 79852,
#    'NewDeaths': 0,
#    'TotalDeaths': 851,
#    'NewRecovered': 0,
#    'TotalRecovered': 75148,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Belgium',
#    'CountryCode': 'BE',
#    'Slug': 'belgium',
#    'NewConfirmed': 2612,
#    'TotalConfirmed': 130235,
#    'NewDeaths': 20,
#    'TotalDeaths': 10064,
#    'NewRecovered': 34,
#    'TotalRecovered': 19679,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Belize',
#    'CountryCode': 'BZ',
#    'Slug': 'belize',
#    'NewConfirmed': 51,
#    'TotalConfirmed': 2131,
#    'NewDeaths': 1,
#    'TotalDeaths': 29,
#    'NewRecovered': 56,
#    'TotalRecovered': 1346,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Benin',
#    'CountryCode': 'BJ',
#    'Slug': 'benin',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2357,
#    'NewDeaths': 0,
#    'TotalDeaths': 41,
#    'NewRecovered': 0,
#    'TotalRecovered': 1973,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Bhutan',
#    'CountryCode': 'BT',
#    'Slug': 'bhutan',
#    'NewConfirmed': 15,
#    'TotalConfirmed': 298,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 7,
#    'TotalRecovered': 237,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Bolivia',
#    'CountryCode': 'BO',
#    'Slug': 'bolivia',
#    'NewConfirmed': 299,
#    'TotalConfirmed': 136868,
#    'NewDeaths': 28,
#    'TotalDeaths': 8101,
#    'NewRecovered': 442,
#    'TotalRecovered': 97547,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Bosnia and Herzegovina',
#    'CountryCode': 'BA',
#    'Slug': 'bosnia-and-herzegovina',
#    'NewConfirmed': 379,
#    'TotalConfirmed': 28354,
#    'NewDeaths': 8,
#    'TotalDeaths': 879,
#    'NewRecovered': 751,
#    'TotalRecovered': 21859,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Botswana',
#    'CountryCode': 'BW',
#    'Slug': 'botswana',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 3172,
#    'NewDeaths': 0,
#    'TotalDeaths': 16,
#    'NewRecovered': 0,
#    'TotalRecovered': 710,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Brazil',
#    'CountryCode': 'BR',
#    'Slug': 'brazil',
#    'NewConfirmed': 8456,
#    'TotalConfirmed': 4915289,
#    'NewDeaths': 365,
#    'TotalDeaths': 146352,
#    'NewRecovered': 14246,
#    'TotalRecovered': 4375354,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Brunei Darussalam',
#    'CountryCode': 'BN',
#    'Slug': 'brunei',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 146,
#    'NewDeaths': 0,
#    'TotalDeaths': 3,
#    'NewRecovered': 0,
#    'TotalRecovered': 142,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Bulgaria',
#    'CountryCode': 'BG',
#    'Slug': 'bulgaria',
#    'NewConfirmed': 69,
#    'TotalConfirmed': 21587,
#    'NewDeaths': 3,
#    'TotalDeaths': 844,
#    'NewRecovered': 30,
#    'TotalRecovered': 15014,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Burkina Faso',
#    'CountryCode': 'BF',
#    'Slug': 'burkina-faso',
#    'NewConfirmed': 13,
#    'TotalConfirmed': 2167,
#    'NewDeaths': 0,
#    'TotalDeaths': 59,
#    'NewRecovered': 22,
#    'TotalRecovered': 1419,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Burundi',
#    'CountryCode': 'BI',
#    'Slug': 'burundi',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 513,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 472,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Cambodia',
#    'CountryCode': 'KH',
#    'Slug': 'cambodia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 278,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 275,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Cameroon',
#    'CountryCode': 'CM',
#    'Slug': 'cameroon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 20924,
#    'NewDeaths': 0,
#    'TotalDeaths': 420,
#    'NewRecovered': 0,
#    'TotalRecovered': 19764,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Canada',
#    'CountryCode': 'CA',
#    'Slug': 'canada',
#    'NewConfirmed': 2141,
#    'TotalConfirmed': 168488,
#    'NewDeaths': 45,
#    'TotalDeaths': 9532,
#    'NewRecovered': 1791,
#    'TotalRecovered': 142502,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Cape Verde',
#    'CountryCode': 'CV',
#    'Slug': 'cape-verde',
#    'NewConfirmed': 64,
#    'TotalConfirmed': 6360,
#    'NewDeaths': 3,
#    'TotalDeaths': 65,
#    'NewRecovered': 7,
#    'TotalRecovered': 5416,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Central African Republic',
#    'CountryCode': 'CF',
#    'Slug': 'central-african-republic',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 4845,
#    'NewDeaths': 0,
#    'TotalDeaths': 62,
#    'NewRecovered': 0,
#    'TotalRecovered': 1914,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Chad',
#    'CountryCode': 'TD',
#    'Slug': 'chad',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 1217,
#    'NewDeaths': 1,
#    'TotalDeaths': 86,
#    'NewRecovered': 0,
#    'TotalRecovered': 1075,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Chile',
#    'CountryCode': 'CL',
#    'Slug': 'chile',
#    'NewConfirmed': 1708,
#    'TotalConfirmed': 470179,
#    'NewDeaths': 60,
#    'TotalDeaths': 12979,
#    'NewRecovered': 1189,
#    'TotalRecovered': 442070,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'China',
#    'CountryCode': 'CN',
#    'Slug': 'china',
#    'NewConfirmed': 25,
#    'TotalConfirmed': 90629,
#    'NewDeaths': 0,
#    'TotalDeaths': 4739,
#    'NewRecovered': 19,
#    'TotalRecovered': 85530,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Colombia',
#    'CountryCode': 'CO',
#    'Slug': 'colombia',
#    'NewConfirmed': 6905,
#    'TotalConfirmed': 855052,
#    'NewDeaths': 156,
#    'TotalDeaths': 26712,
#    'NewRecovered': 3873,
#    'TotalRecovered': 761674,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Comoros',
#    'CountryCode': 'KM',
#    'Slug': 'comoros',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 487,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 0,
#    'TotalRecovered': 466,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Congo (Brazzaville)',
#    'CountryCode': 'CG',
#    'Slug': 'congo-brazzaville',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5089,
#    'NewDeaths': 0,
#    'TotalDeaths': 89,
#    'NewRecovered': 0,
#    'TotalRecovered': 3887,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Congo (Kinshasa)',
#    'CountryCode': 'CD',
#    'Slug': 'congo-kinshasa',
#    'NewConfirmed': 8,
#    'TotalConfirmed': 10760,
#    'NewDeaths': 0,
#    'TotalDeaths': 274,
#    'NewRecovered': 27,
#    'TotalRecovered': 10239,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Costa Rica',
#    'CountryCode': 'CR',
#    'Slug': 'costa-rica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 79182,
#    'NewDeaths': 0,
#    'TotalDeaths': 950,
#    'NewRecovered': 0,
#    'TotalRecovered': 45007,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Croatia',
#    'CountryCode': 'HR',
#    'Slug': 'croatia',
#    'NewConfirmed': 258,
#    'TotalConfirmed': 17659,
#    'NewDeaths': 5,
#    'TotalDeaths': 298,
#    'NewRecovered': 188,
#    'TotalRecovered': 15849,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Cuba',
#    'CountryCode': 'CU',
#    'Slug': 'cuba',
#    'NewConfirmed': 29,
#    'TotalConfirmed': 5809,
#    'NewDeaths': 0,
#    'TotalDeaths': 122,
#    'NewRecovered': 27,
#    'TotalRecovered': 5145,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Cyprus',
#    'CountryCode': 'CY',
#    'Slug': 'cyprus',
#    'NewConfirmed': 13,
#    'TotalConfirmed': 1824,
#    'NewDeaths': 0,
#    'TotalDeaths': 22,
#    'NewRecovered': 0,
#    'TotalRecovered': 1369,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Czech Republic',
#    'CountryCode': 'CZ',
#    'Slug': 'czech-republic',
#    'NewConfirmed': 1841,
#    'TotalConfirmed': 82446,
#    'NewDeaths': 16,
#    'TotalDeaths': 727,
#    'NewRecovered': 5076,
#    'TotalRecovered': 44149,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': "Côte d'Ivoire",
#    'CountryCode': 'CI',
#    'Slug': 'cote-divoire',
#    'NewConfirmed': 33,
#    'TotalConfirmed': 19882,
#    'NewDeaths': 0,
#    'TotalDeaths': 120,
#    'NewRecovered': 28,
#    'TotalRecovered': 19449,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Denmark',
#    'CountryCode': 'DK',
#    'Slug': 'denmark',
#    'NewConfirmed': 379,
#    'TotalConfirmed': 30168,
#    'NewDeaths': 4,
#    'TotalDeaths': 658,
#    'NewRecovered': 422,
#    'TotalRecovered': 23165,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Djibouti',
#    'CountryCode': 'DJ',
#    'Slug': 'djibouti',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 5419,
#    'NewDeaths': 0,
#    'TotalDeaths': 61,
#    'NewRecovered': 2,
#    'TotalRecovered': 5349,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Dominica',
#    'CountryCode': 'DM',
#    'Slug': 'dominica',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 31,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 24,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Dominican Republic',
#    'CountryCode': 'DO',
#    'Slug': 'dominican-republic',
#    'NewConfirmed': 554,
#    'TotalConfirmed': 114480,
#    'NewDeaths': 6,
#    'TotalDeaths': 2134,
#    'NewRecovered': 731,
#    'TotalRecovered': 90366,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Ecuador',
#    'CountryCode': 'EC',
#    'Slug': 'ecuador',
#    'NewConfirmed': 683,
#    'TotalConfirmed': 141034,
#    'NewDeaths': 50,
#    'TotalDeaths': 11647,
#    'NewRecovered': 8215,
#    'TotalRecovered': 120511,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Egypt',
#    'CountryCode': 'EG',
#    'Slug': 'egypt',
#    'NewConfirmed': 108,
#    'TotalConfirmed': 103683,
#    'NewDeaths': 11,
#    'TotalDeaths': 5981,
#    'NewRecovered': 81,
#    'TotalRecovered': 97355,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'El Salvador',
#    'CountryCode': 'SV',
#    'Slug': 'el-salvador',
#    'NewConfirmed': 92,
#    'TotalConfirmed': 29450,
#    'NewDeaths': 6,
#    'TotalDeaths': 863,
#    'NewRecovered': 121,
#    'TotalRecovered': 24296,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Equatorial Guinea',
#    'CountryCode': 'GQ',
#    'Slug': 'equatorial-guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5045,
#    'NewDeaths': 0,
#    'TotalDeaths': 83,
#    'NewRecovered': 0,
#    'TotalRecovered': 4879,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Eritrea',
#    'CountryCode': 'ER',
#    'Slug': 'eritrea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 398,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 358,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Estonia',
#    'CountryCode': 'EE',
#    'Slug': 'estonia',
#    'NewConfirmed': 30,
#    'TotalConfirmed': 3607,
#    'NewDeaths': 0,
#    'TotalDeaths': 67,
#    'NewRecovered': 22,
#    'TotalRecovered': 2749,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Ethiopia',
#    'CountryCode': 'ET',
#    'Slug': 'ethiopia',
#    'NewConfirmed': 959,
#    'TotalConfirmed': 78819,
#    'NewDeaths': 8,
#    'TotalDeaths': 1222,
#    'NewRecovered': 735,
#    'TotalRecovered': 33060,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Fiji',
#    'CountryCode': 'FJ',
#    'Slug': 'fiji',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 32,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 0,
#    'TotalRecovered': 28,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Finland',
#    'CountryCode': 'FI',
#    'Slug': 'finland',
#    'NewConfirmed': 147,
#    'TotalConfirmed': 10538,
#    'NewDeaths': 0,
#    'TotalDeaths': 345,
#    'NewRecovered': 0,
#    'TotalRecovered': 8100,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'France',
#    'CountryCode': 'FR',
#    'Slug': 'france',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 629509,
#    'NewDeaths': 0,
#    'TotalDeaths': 32171,
#    'NewRecovered': 0,
#    'TotalRecovered': 100281,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Gabon',
#    'CountryCode': 'GA',
#    'Slug': 'gabon',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8797,
#    'NewDeaths': 0,
#    'TotalDeaths': 54,
#    'NewRecovered': 0,
#    'TotalRecovered': 8067,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Gambia',
#    'CountryCode': 'GM',
#    'Slug': 'gambia',
#    'NewConfirmed': 4,
#    'TotalConfirmed': 3594,
#    'NewDeaths': 0,
#    'TotalDeaths': 115,
#    'NewRecovered': 0,
#    'TotalRecovered': 2226,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Georgia',
#    'CountryCode': 'GE',
#    'Slug': 'georgia',
#    'NewConfirmed': 554,
#    'TotalConfirmed': 8118,
#    'NewDeaths': 2,
#    'TotalDeaths': 50,
#    'NewRecovered': 252,
#    'TotalRecovered': 4244,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Germany',
#    'CountryCode': 'DE',
#    'Slug': 'germany',
#    'NewConfirmed': 1546,
#    'TotalConfirmed': 301573,
#    'NewDeaths': 2,
#    'TotalDeaths': 9533,
#    'NewRecovered': 1086,
#    'TotalRecovered': 262002,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Ghana',
#    'CountryCode': 'GH',
#    'Slug': 'ghana',
#    'NewConfirmed': 26,
#    'TotalConfirmed': 46829,
#    'NewDeaths': 0,
#    'TotalDeaths': 303,
#    'NewRecovered': 54,
#    'TotalRecovered': 46060,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Greece',
#    'CountryCode': 'GR',
#    'Slug': 'greece',
#    'NewConfirmed': 229,
#    'TotalConfirmed': 19842,
#    'NewDeaths': 4,
#    'TotalDeaths': 409,
#    'NewRecovered': 0,
#    'TotalRecovered': 1347,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Grenada',
#    'CountryCode': 'GD',
#    'Slug': 'grenada',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 24,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 24,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Guatemala',
#    'CountryCode': 'GT',
#    'Slug': 'guatemala',
#    'NewConfirmed': 215,
#    'TotalConfirmed': 93963,
#    'NewDeaths': 8,
#    'TotalDeaths': 3293,
#    'NewRecovered': 414,
#    'TotalRecovered': 82454,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Guinea',
#    'CountryCode': 'GN',
#    'Slug': 'guinea',
#    'NewConfirmed': 19,
#    'TotalConfirmed': 10754,
#    'NewDeaths': 0,
#    'TotalDeaths': 66,
#    'NewRecovered': 32,
#    'TotalRecovered': 10098,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Guinea-Bissau',
#    'CountryCode': 'GW',
#    'Slug': 'guinea-bissau',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2362,
#    'NewDeaths': 0,
#    'TotalDeaths': 39,
#    'NewRecovered': 0,
#    'TotalRecovered': 1549,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Guyana',
#    'CountryCode': 'GY',
#    'Slug': 'guyana',
#    'NewConfirmed': 125,
#    'TotalConfirmed': 3093,
#    'NewDeaths': 2,
#    'TotalDeaths': 87,
#    'NewRecovered': 144,
#    'TotalRecovered': 1920,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Haiti',
#    'CountryCode': 'HT',
#    'Slug': 'haiti',
#    'NewConfirmed': 8,
#    'TotalConfirmed': 8819,
#    'NewDeaths': 0,
#    'TotalDeaths': 229,
#    'NewRecovered': 43,
#    'TotalRecovered': 6992,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Holy See (Vatican City State)',
#    'CountryCode': 'VA',
#    'Slug': 'holy-see-vatican-city-state',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 12,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 12,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Honduras',
#    'CountryCode': 'HN',
#    'Slug': 'honduras',
#    'NewConfirmed': 841,
#    'TotalConfirmed': 79629,
#    'NewDeaths': 23,
#    'TotalDeaths': 2422,
#    'NewRecovered': 118,
#    'TotalRecovered': 29305,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Hungary',
#    'CountryCode': 'HU',
#    'Slug': 'hungary',
#    'NewConfirmed': 858,
#    'TotalConfirmed': 30575,
#    'NewDeaths': 10,
#    'TotalDeaths': 822,
#    'NewRecovered': 646,
#    'TotalRecovered': 7470,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Iceland',
#    'CountryCode': 'IS',
#    'Slug': 'iceland',
#    'NewConfirmed': 49,
#    'TotalConfirmed': 2921,
#    'NewDeaths': 0,
#    'TotalDeaths': 10,
#    'NewRecovered': 65,
#    'TotalRecovered': 2277,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'India',
#    'CountryCode': 'IN',
#    'Slug': 'india',
#    'NewConfirmed': 74442,
#    'TotalConfirmed': 6623815,
#    'NewDeaths': 903,
#    'TotalDeaths': 102685,
#    'NewRecovered': 76737,
#    'TotalRecovered': 5586703,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Indonesia',
#    'CountryCode': 'ID',
#    'Slug': 'indonesia',
#    'NewConfirmed': 3992,
#    'TotalConfirmed': 303498,
#    'NewDeaths': 96,
#    'TotalDeaths': 11151,
#    'NewRecovered': 3401,
#    'TotalRecovered': 228453,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Iran, Islamic Republic of',
#    'CountryCode': 'IR',
#    'Slug': 'iran',
#    'NewConfirmed': 3653,
#    'TotalConfirmed': 471772,
#    'NewDeaths': 211,
#    'TotalDeaths': 26957,
#    'NewRecovered': 2291,
#    'TotalRecovered': 389966,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Iraq',
#    'CountryCode': 'IQ',
#    'Slug': 'iraq',
#    'NewConfirmed': 3210,
#    'TotalConfirmed': 379141,
#    'NewDeaths': 52,
#    'TotalDeaths': 9399,
#    'NewRecovered': 3817,
#    'TotalRecovered': 307482,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Ireland',
#    'CountryCode': 'IE',
#    'Slug': 'ireland',
#    'NewConfirmed': 364,
#    'TotalConfirmed': 38032,
#    'NewDeaths': 0,
#    'TotalDeaths': 1810,
#    'NewRecovered': 0,
#    'TotalRecovered': 23364,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Israel',
#    'CountryCode': 'IL',
#    'Slug': 'israel',
#    'NewConfirmed': 2332,
#    'TotalConfirmed': 266775,
#    'NewDeaths': 37,
#    'TotalDeaths': 1719,
#    'NewRecovered': 4378,
#    'TotalRecovered': 195629,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Italy',
#    'CountryCode': 'IT',
#    'Slug': 'italy',
#    'NewConfirmed': 2578,
#    'TotalConfirmed': 325329,
#    'NewDeaths': 18,
#    'TotalDeaths': 35986,
#    'NewRecovered': 697,
#    'TotalRecovered': 231914,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Jamaica',
#    'CountryCode': 'JM',
#    'Slug': 'jamaica',
#    'NewConfirmed': 100,
#    'TotalConfirmed': 6895,
#    'NewDeaths': 1,
#    'TotalDeaths': 120,
#    'NewRecovered': 115,
#    'TotalRecovered': 2460,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Japan',
#    'CountryCode': 'JP',
#    'Slug': 'japan',
#    'NewConfirmed': 401,
#    'TotalConfirmed': 85746,
#    'NewDeaths': 4,
#    'TotalDeaths': 1598,
#    'NewRecovered': 1151,
#    'TotalRecovered': 77851,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Jordan',
#    'CountryCode': 'JO',
#    'Slug': 'jordan',
#    'NewConfirmed': 891,
#    'TotalConfirmed': 15640,
#    'NewDeaths': 13,
#    'TotalDeaths': 101,
#    'NewRecovered': 139,
#    'TotalRecovered': 5240,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Kazakhstan',
#    'CountryCode': 'KZ',
#    'Slug': 'kazakhstan',
#    'NewConfirmed': 59,
#    'TotalConfirmed': 108236,
#    'NewDeaths': 0,
#    'TotalDeaths': 1725,
#    'NewRecovered': 72,
#    'TotalRecovered': 103277,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Kenya',
#    'CountryCode': 'KE',
#    'Slug': 'kenya',
#    'NewConfirmed': 243,
#    'TotalConfirmed': 39427,
#    'NewDeaths': 3,
#    'TotalDeaths': 731,
#    'NewRecovered': 233,
#    'TotalRecovered': 25659,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Korea (South)',
#    'CountryCode': 'KR',
#    'Slug': 'korea-south',
#    'NewConfirmed': 73,
#    'TotalConfirmed': 24164,
#    'NewDeaths': 1,
#    'TotalDeaths': 422,
#    'NewRecovered': 41,
#    'TotalRecovered': 21886,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Kuwait',
#    'CountryCode': 'KW',
#    'Slug': 'kuwait',
#    'NewConfirmed': 567,
#    'TotalConfirmed': 107025,
#    'NewDeaths': 4,
#    'TotalDeaths': 624,
#    'NewRecovered': 605,
#    'TotalRecovered': 99040,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Kyrgyzstan',
#    'CountryCode': 'KG',
#    'Slug': 'kyrgyzstan',
#    'NewConfirmed': 244,
#    'TotalConfirmed': 47428,
#    'NewDeaths': 0,
#    'TotalDeaths': 1066,
#    'NewRecovered': 140,
#    'TotalRecovered': 43418,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Lao PDR',
#    'CountryCode': 'LA',
#    'Slug': 'lao-pdr',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 23,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 22,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Latvia',
#    'CountryCode': 'LV',
#    'Slug': 'latvia',
#    'NewConfirmed': 67,
#    'TotalConfirmed': 2086,
#    'NewDeaths': 0,
#    'TotalDeaths': 38,
#    'NewRecovered': 0,
#    'TotalRecovered': 1307,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Lebanon',
#    'CountryCode': 'LB',
#    'Slug': 'lebanon',
#    'NewConfirmed': 988,
#    'TotalConfirmed': 44482,
#    'NewDeaths': 8,
#    'TotalDeaths': 406,
#    'NewRecovered': 523,
#    'TotalRecovered': 19782,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Lesotho',
#    'CountryCode': 'LS',
#    'Slug': 'lesotho',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 1683,
#    'NewDeaths': 0,
#    'TotalDeaths': 39,
#    'NewRecovered': 0,
#    'TotalRecovered': 926,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Liberia',
#    'CountryCode': 'LR',
#    'Slug': 'liberia',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 1348,
#    'NewDeaths': 0,
#    'TotalDeaths': 82,
#    'NewRecovered': 15,
#    'TotalRecovered': 1236,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Libya',
#    'CountryCode': 'LY',
#    'Slug': 'libya',
#    'NewConfirmed': 722,
#    'TotalConfirmed': 36809,
#    'NewDeaths': 14,
#    'TotalDeaths': 592,
#    'NewRecovered': 540,
#    'TotalRecovered': 21429,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Liechtenstein',
#    'CountryCode': 'LI',
#    'Slug': 'liechtenstein',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 126,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 116,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Lithuania',
#    'CountryCode': 'LT',
#    'Slug': 'lithuania',
#    'NewConfirmed': 104,
#    'TotalConfirmed': 5185,
#    'NewDeaths': 0,
#    'TotalDeaths': 94,
#    'NewRecovered': 1,
#    'TotalRecovered': 2495,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Luxembourg',
#    'CountryCode': 'LU',
#    'Slug': 'luxembourg',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 8709,
#    'NewDeaths': 0,
#    'TotalDeaths': 125,
#    'NewRecovered': 0,
#    'TotalRecovered': 7428,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Macao, SAR China',
#    'CountryCode': 'MO',
#    'Slug': 'macao-sar-china',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Macedonia, Republic of',
#    'CountryCode': 'MK',
#    'Slug': 'macedonia',
#    'NewConfirmed': 188,
#    'TotalConfirmed': 18790,
#    'NewDeaths': 3,
#    'TotalDeaths': 756,
#    'NewRecovered': 77,
#    'TotalRecovered': 15341,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Madagascar',
#    'CountryCode': 'MG',
#    'Slug': 'madagascar',
#    'NewConfirmed': 29,
#    'TotalConfirmed': 16558,
#    'NewDeaths': 0,
#    'TotalDeaths': 232,
#    'NewRecovered': 6,
#    'TotalRecovered': 15486,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Malawi',
#    'CountryCode': 'MW',
#    'Slug': 'malawi',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 5786,
#    'NewDeaths': 0,
#    'TotalDeaths': 179,
#    'NewRecovered': 2,
#    'TotalRecovered': 4541,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Malaysia',
#    'CountryCode': 'MY',
#    'Slug': 'malaysia',
#    'NewConfirmed': 293,
#    'TotalConfirmed': 12381,
#    'NewDeaths': 0,
#    'TotalDeaths': 137,
#    'NewRecovered': 67,
#    'TotalRecovered': 10283,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Maldives',
#    'CountryCode': 'MV',
#    'Slug': 'maldives',
#    'NewConfirmed': 65,
#    'TotalConfirmed': 10530,
#    'NewDeaths': 0,
#    'TotalDeaths': 34,
#    'NewRecovered': 54,
#    'TotalRecovered': 9364,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Mali',
#    'CountryCode': 'ML',
#    'Slug': 'mali',
#    'NewConfirmed': 14,
#    'TotalConfirmed': 3184,
#    'NewDeaths': 0,
#    'TotalDeaths': 131,
#    'NewRecovered': 3,
#    'TotalRecovered': 2479,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Malta',
#    'CountryCode': 'MT',
#    'Slug': 'malta',
#    'NewConfirmed': 66,
#    'TotalConfirmed': 3270,
#    'NewDeaths': 1,
#    'TotalDeaths': 39,
#    'NewRecovered': 47,
#    'TotalRecovered': 2758,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Mauritania',
#    'CountryCode': 'MR',
#    'Slug': 'mauritania',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 7520,
#    'NewDeaths': 0,
#    'TotalDeaths': 162,
#    'NewRecovered': 14,
#    'TotalRecovered': 7188,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Mauritius',
#    'CountryCode': 'MU',
#    'Slug': 'mauritius',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 385,
#    'NewDeaths': 0,
#    'TotalDeaths': 10,
#    'NewRecovered': 0,
#    'TotalRecovered': 357,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Mexico',
#    'CountryCode': 'MX',
#    'Slug': 'mexico',
#    'NewConfirmed': 3712,
#    'TotalConfirmed': 761665,
#    'NewDeaths': 208,
#    'TotalDeaths': 79088,
#    'NewRecovered': 7130,
#    'TotalRecovered': 645123,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Moldova',
#    'CountryCode': 'MD',
#    'Slug': 'moldova',
#    'NewConfirmed': 691,
#    'TotalConfirmed': 56579,
#    'NewDeaths': 13,
#    'TotalDeaths': 1366,
#    'NewRecovered': 480,
#    'TotalRecovered': 40955,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Monaco',
#    'CountryCode': 'MC',
#    'Slug': 'monaco',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 222,
#    'NewDeaths': 0,
#    'TotalDeaths': 2,
#    'NewRecovered': 1,
#    'TotalRecovered': 189,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Mongolia',
#    'CountryCode': 'MN',
#    'Slug': 'mongolia',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 314,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 307,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Montenegro',
#    'CountryCode': 'ME',
#    'Slug': 'montenegro',
#    'NewConfirmed': 193,
#    'TotalConfirmed': 12127,
#    'NewDeaths': 5,
#    'TotalDeaths': 179,
#    'NewRecovered': 150,
#    'TotalRecovered': 7953,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Morocco',
#    'CountryCode': 'MA',
#    'Slug': 'morocco',
#    'NewConfirmed': 2044,
#    'TotalConfirmed': 133272,
#    'NewDeaths': 37,
#    'TotalDeaths': 2330,
#    'NewRecovered': 2349,
#    'TotalRecovered': 111036,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Mozambique',
#    'CountryCode': 'MZ',
#    'Slug': 'mozambique',
#    'NewConfirmed': 147,
#    'TotalConfirmed': 9196,
#    'NewDeaths': 2,
#    'TotalDeaths': 66,
#    'NewRecovered': 116,
#    'TotalRecovered': 5852,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Myanmar',
#    'CountryCode': 'MM',
#    'Slug': 'myanmar',
#    'NewConfirmed': 1291,
#    'TotalConfirmed': 17794,
#    'NewDeaths': 41,
#    'TotalDeaths': 412,
#    'NewRecovered': 400,
#    'TotalRecovered': 5195,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Namibia',
#    'CountryCode': 'NA',
#    'Slug': 'namibia',
#    'NewConfirmed': 54,
#    'TotalConfirmed': 11626,
#    'NewDeaths': 0,
#    'TotalDeaths': 123,
#    'NewRecovered': 10,
#    'TotalRecovered': 9429,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Nepal',
#    'CountryCode': 'NP',
#    'Slug': 'nepal',
#    'NewConfirmed': 2253,
#    'TotalConfirmed': 86823,
#    'NewDeaths': 7,
#    'TotalDeaths': 535,
#    'NewRecovered': 1329,
#    'TotalRecovered': 64069,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Netherlands',
#    'CountryCode': 'NL',
#    'Slug': 'netherlands',
#    'NewConfirmed': 4003,
#    'TotalConfirmed': 135892,
#    'NewDeaths': 5,
#    'TotalDeaths': 6454,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'New Zealand',
#    'CountryCode': 'NZ',
#    'Slug': 'new-zealand',
#    'NewConfirmed': 1,
#    'TotalConfirmed': 1855,
#    'NewDeaths': 0,
#    'TotalDeaths': 25,
#    'NewRecovered': 2,
#    'TotalRecovered': 1790,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Nicaragua',
#    'CountryCode': 'NI',
#    'Slug': 'nicaragua',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 5170,
#    'NewDeaths': 0,
#    'TotalDeaths': 151,
#    'NewRecovered': 0,
#    'TotalRecovered': 2913,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Niger',
#    'CountryCode': 'NE',
#    'Slug': 'niger',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1200,
#    'NewDeaths': 0,
#    'TotalDeaths': 69,
#    'NewRecovered': 0,
#    'TotalRecovered': 1115,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Nigeria',
#    'CountryCode': 'NG',
#    'Slug': 'nigeria',
#    'NewConfirmed': 58,
#    'TotalConfirmed': 59345,
#    'NewDeaths': 0,
#    'TotalDeaths': 1113,
#    'NewRecovered': 50,
#    'TotalRecovered': 50768,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Norway',
#    'CountryCode': 'NO',
#    'Slug': 'norway',
#    'NewConfirmed': 95,
#    'TotalConfirmed': 14457,
#    'NewDeaths': 0,
#    'TotalDeaths': 275,
#    'NewRecovered': 0,
#    'TotalRecovered': 11190,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Oman',
#    'CountryCode': 'OM',
#    'Slug': 'oman',
#    'NewConfirmed': 2685,
#    'TotalConfirmed': 101270,
#    'NewDeaths': 42,
#    'TotalDeaths': 977,
#    'NewRecovered': 1768,
#    'TotalRecovered': 90296,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Pakistan',
#    'CountryCode': 'PK',
#    'Slug': 'pakistan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 314616,
#    'NewDeaths': 0,
#    'TotalDeaths': 6513,
#    'NewRecovered': 0,
#    'TotalRecovered': 298968,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Palestinian Territory',
#    'CountryCode': 'PS',
#    'Slug': 'palestine',
#    'NewConfirmed': 420,
#    'TotalConfirmed': 41498,
#    'NewDeaths': 1,
#    'TotalDeaths': 330,
#    'NewRecovered': 1256,
#    'TotalRecovered': 34698,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Panama',
#    'CountryCode': 'PA',
#    'Slug': 'panama',
#    'NewConfirmed': 633,
#    'TotalConfirmed': 115286,
#    'NewDeaths': 9,
#    'TotalDeaths': 2423,
#    'NewRecovered': 614,
#    'TotalRecovered': 91809,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Papua New Guinea',
#    'CountryCode': 'PG',
#    'Slug': 'papua-new-guinea',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 540,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 0,
#    'TotalRecovered': 527,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Paraguay',
#    'CountryCode': 'PY',
#    'Slug': 'paraguay',
#    'NewConfirmed': 730,
#    'TotalConfirmed': 44182,
#    'NewDeaths': 16,
#    'TotalDeaths': 929,
#    'NewRecovered': 691,
#    'TotalRecovered': 27203,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Peru',
#    'CountryCode': 'PE',
#    'Slug': 'peru',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 821564,
#    'NewDeaths': 0,
#    'TotalDeaths': 32609,
#    'NewRecovered': 5223,
#    'TotalRecovered': 700868,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Philippines',
#    'CountryCode': 'PH',
#    'Slug': 'philippines',
#    'NewConfirmed': 3167,
#    'TotalConfirmed': 322497,
#    'NewDeaths': 98,
#    'TotalDeaths': 5776,
#    'NewRecovered': 18033,
#    'TotalRecovered': 273079,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Poland',
#    'CountryCode': 'PL',
#    'Slug': 'poland',
#    'NewConfirmed': 1934,
#    'TotalConfirmed': 100074,
#    'NewDeaths': 26,
#    'TotalDeaths': 2630,
#    'NewRecovered': 794,
#    'TotalRecovered': 73003,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Portugal',
#    'CountryCode': 'PT',
#    'Slug': 'portugal',
#    'NewConfirmed': 904,
#    'TotalConfirmed': 79151,
#    'NewDeaths': 10,
#    'TotalDeaths': 2005,
#    'NewRecovered': 362,
#    'TotalRecovered': 50207,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Qatar',
#    'CountryCode': 'QA',
#    'Slug': 'qatar',
#    'NewConfirmed': 159,
#    'TotalConfirmed': 126498,
#    'NewDeaths': 0,
#    'TotalDeaths': 216,
#    'NewRecovered': 173,
#    'TotalRecovered': 123475,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Republic of Kosovo',
#    'CountryCode': 'XK',
#    'Slug': 'kosovo',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 12683,
#    'NewDeaths': 0,
#    'TotalDeaths': 488,
#    'NewRecovered': 0,
#    'TotalRecovered': 8788,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Romania',
#    'CountryCode': 'RO',
#    'Slug': 'romania',
#    'NewConfirmed': 1835,
#    'TotalConfirmed': 135900,
#    'NewDeaths': 56,
#    'TotalDeaths': 5003,
#    'NewRecovered': 1077,
#    'TotalRecovered': 108135,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Russian Federation',
#    'CountryCode': 'RU',
#    'Slug': 'russia',
#    'NewConfirmed': 10376,
#    'TotalConfirmed': 1209039,
#    'NewDeaths': 107,
#    'TotalDeaths': 21260,
#    'NewRecovered': 3239,
#    'TotalRecovered': 975488,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Rwanda',
#    'CountryCode': 'RW',
#    'Slug': 'rwanda',
#    'NewConfirmed': 14,
#    'TotalConfirmed': 4866,
#    'NewDeaths': 0,
#    'TotalDeaths': 29,
#    'NewRecovered': 5,
#    'TotalRecovered': 3216,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Réunion',
#    'CountryCode': 'RE',
#    'Slug': 'réunion',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 0,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Saint Kitts and Nevis',
#    'CountryCode': 'KN',
#    'Slug': 'saint-kitts-and-nevis',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 19,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 17,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Saint Lucia',
#    'CountryCode': 'LC',
#    'Slug': 'saint-lucia',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 27,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 27,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Saint Vincent and Grenadines',
#    'CountryCode': 'VC',
#    'Slug': 'saint-vincent-and-the-grenadines',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 64,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 64,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'San Marino',
#    'CountryCode': 'SM',
#    'Slug': 'san-marino',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 732,
#    'NewDeaths': 0,
#    'TotalDeaths': 42,
#    'NewRecovered': 0,
#    'TotalRecovered': 680,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Sao Tome and Principe',
#    'CountryCode': 'ST',
#    'Slug': 'sao-tome-and-principe',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 913,
#    'NewDeaths': 0,
#    'TotalDeaths': 15,
#    'NewRecovered': 1,
#    'TotalRecovered': 887,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Saudi Arabia',
#    'CountryCode': 'SA',
#    'Slug': 'saudi-arabia',
#    'NewConfirmed': 390,
#    'TotalConfirmed': 336387,
#    'NewDeaths': 25,
#    'TotalDeaths': 4875,
#    'NewRecovered': 511,
#    'TotalRecovered': 321485,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Senegal',
#    'CountryCode': 'SN',
#    'Slug': 'senegal',
#    'NewConfirmed': 26,
#    'TotalConfirmed': 15094,
#    'NewDeaths': 0,
#    'TotalDeaths': 312,
#    'NewRecovered': 54,
#    'TotalRecovered': 12805,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Serbia',
#    'CountryCode': 'RS',
#    'Slug': 'serbia',
#    'NewConfirmed': 59,
#    'TotalConfirmed': 33901,
#    'NewDeaths': 1,
#    'TotalDeaths': 754,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Seychelles',
#    'CountryCode': 'SC',
#    'Slug': 'seychelles',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 146,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 143,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Sierra Leone',
#    'CountryCode': 'SL',
#    'Slug': 'sierra-leone',
#    'NewConfirmed': 10,
#    'TotalConfirmed': 2269,
#    'NewDeaths': 0,
#    'TotalDeaths': 72,
#    'NewRecovered': 2,
#    'TotalRecovered': 1706,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Singapore',
#    'CountryCode': 'SG',
#    'Slug': 'singapore',
#    'NewConfirmed': 12,
#    'TotalConfirmed': 57812,
#    'NewDeaths': 0,
#    'TotalDeaths': 27,
#    'NewRecovered': 13,
#    'TotalRecovered': 57575,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Slovakia',
#    'CountryCode': 'SK',
#    'Slug': 'slovakia',
#    'NewConfirmed': 818,
#    'TotalConfirmed': 13139,
#    'NewDeaths': 1,
#    'TotalDeaths': 55,
#    'NewRecovered': 35,
#    'TotalRecovered': 4828,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Slovenia',
#    'CountryCode': 'SI',
#    'Slug': 'slovenia',
#    'NewConfirmed': 168,
#    'TotalConfirmed': 6498,
#    'NewDeaths': 0,
#    'TotalDeaths': 155,
#    'NewRecovered': 224,
#    'TotalRecovered': 4265,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Somalia',
#    'CountryCode': 'SO',
#    'Slug': 'somalia',
#    'NewConfirmed': 152,
#    'TotalConfirmed': 3745,
#    'NewDeaths': 0,
#    'TotalDeaths': 99,
#    'NewRecovered': 9,
#    'TotalRecovered': 3010,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'South Africa',
#    'CountryCode': 'ZA',
#    'Slug': 'south-africa',
#    'NewConfirmed': 1573,
#    'TotalConfirmed': 681289,
#    'NewDeaths': 38,
#    'TotalDeaths': 16976,
#    'NewRecovered': 2018,
#    'TotalRecovered': 614781,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'South Sudan',
#    'CountryCode': 'SS',
#    'Slug': 'south-sudan',
#    'NewConfirmed': 11,
#    'TotalConfirmed': 2726,
#    'NewDeaths': 0,
#    'TotalDeaths': 50,
#    'NewRecovered': 0,
#    'TotalRecovered': 1290,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Spain',
#    'CountryCode': 'ES',
#    'Slug': 'spain',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 789932,
#    'NewDeaths': 0,
#    'TotalDeaths': 32086,
#    'NewRecovered': 0,
#    'TotalRecovered': 150376,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Sri Lanka',
#    'CountryCode': 'LK',
#    'Slug': 'sri-lanka',
#    'NewConfirmed': 7,
#    'TotalConfirmed': 3402,
#    'NewDeaths': 0,
#    'TotalDeaths': 13,
#    'NewRecovered': 4,
#    'TotalRecovered': 3258,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Sudan',
#    'CountryCode': 'SD',
#    'Slug': 'sudan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 13653,
#    'NewDeaths': 0,
#    'TotalDeaths': 836,
#    'NewRecovered': 0,
#    'TotalRecovered': 6764,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Suriname',
#    'CountryCode': 'SR',
#    'Slug': 'suriname',
#    'NewConfirmed': 17,
#    'TotalConfirmed': 4941,
#    'NewDeaths': 0,
#    'TotalDeaths': 106,
#    'NewRecovered': 18,
#    'TotalRecovered': 4741,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Swaziland',
#    'CountryCode': 'SZ',
#    'Slug': 'swaziland',
#    'NewConfirmed': 39,
#    'TotalConfirmed': 5569,
#    'NewDeaths': 0,
#    'TotalDeaths': 111,
#    'NewRecovered': 51,
#    'TotalRecovered': 5127,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Sweden',
#    'CountryCode': 'SE',
#    'Slug': 'sweden',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 94283,
#    'NewDeaths': 0,
#    'TotalDeaths': 5895,
#    'NewRecovered': 0,
#    'TotalRecovered': 0,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Switzerland',
#    'CountryCode': 'CH',
#    'Slug': 'switzerland',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 54384,
#    'NewDeaths': 1,
#    'TotalDeaths': 2077,
#    'NewRecovered': 0,
#    'TotalRecovered': 45800,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Syrian Arab Republic (Syria)',
#    'CountryCode': 'SY',
#    'Slug': 'syria',
#    'NewConfirmed': 37,
#    'TotalConfirmed': 4366,
#    'NewDeaths': 1,
#    'TotalDeaths': 205,
#    'NewRecovered': 12,
#    'TotalRecovered': 1155,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Taiwan, Republic of China',
#    'CountryCode': 'TW',
#    'Slug': 'taiwan',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 517,
#    'NewDeaths': 0,
#    'TotalDeaths': 7,
#    'NewRecovered': 0,
#    'TotalRecovered': 484,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Tajikistan',
#    'CountryCode': 'TJ',
#    'Slug': 'tajikistan',
#    'NewConfirmed': 40,
#    'TotalConfirmed': 9935,
#    'NewDeaths': 1,
#    'TotalDeaths': 78,
#    'NewRecovered': 42,
#    'TotalRecovered': 8749,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Tanzania, United Republic of',
#    'CountryCode': 'TZ',
#    'Slug': 'tanzania',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 509,
#    'NewDeaths': 0,
#    'TotalDeaths': 21,
#    'NewRecovered': 0,
#    'TotalRecovered': 183,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Thailand',
#    'CountryCode': 'TH',
#    'Slug': 'thailand',
#    'NewConfirmed': 5,
#    'TotalConfirmed': 3590,
#    'NewDeaths': 0,
#    'TotalDeaths': 59,
#    'NewRecovered': 2,
#    'TotalRecovered': 3390,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Timor-Leste',
#    'CountryCode': 'TL',
#    'Slug': 'timor-leste',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 28,
#    'NewDeaths': 0,
#    'TotalDeaths': 0,
#    'NewRecovered': 0,
#    'TotalRecovered': 28,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Togo',
#    'CountryCode': 'TG',
#    'Slug': 'togo',
#    'NewConfirmed': 14,
#    'TotalConfirmed': 1854,
#    'NewDeaths': 0,
#    'TotalDeaths': 48,
#    'NewRecovered': 17,
#    'TotalRecovered': 1392,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Trinidad and Tobago',
#    'CountryCode': 'TT',
#    'Slug': 'trinidad-and-tobago',
#    'NewConfirmed': 48,
#    'TotalConfirmed': 4763,
#    'NewDeaths': 2,
#    'TotalDeaths': 81,
#    'NewRecovered': 41,
#    'TotalRecovered': 2843,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Tunisia',
#    'CountryCode': 'TN',
#    'Slug': 'tunisia',
#    'NewConfirmed': 1286,
#    'TotalConfirmed': 22230,
#    'NewDeaths': 45,
#    'TotalDeaths': 321,
#    'NewRecovered': 0,
#    'TotalRecovered': 5032,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Turkey',
#    'CountryCode': 'TR',
#    'Slug': 'turkey',
#    'NewConfirmed': 1429,
#    'TotalConfirmed': 324443,
#    'NewDeaths': 57,
#    'TotalDeaths': 8441,
#    'NewRecovered': 1182,
#    'TotalRecovered': 285050,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Uganda',
#    'CountryCode': 'UG',
#    'Slug': 'uganda',
#    'NewConfirmed': 146,
#    'TotalConfirmed': 8808,
#    'NewDeaths': 2,
#    'TotalDeaths': 81,
#    'NewRecovered': 190,
#    'TotalRecovered': 4736,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Ukraine',
#    'CountryCode': 'UA',
#    'Slug': 'ukraine',
#    'NewConfirmed': 4263,
#    'TotalConfirmed': 232424,
#    'NewDeaths': 44,
#    'TotalDeaths': 4495,
#    'NewRecovered': 1415,
#    'TotalRecovered': 103762,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'United Arab Emirates',
#    'CountryCode': 'AE',
#    'Slug': 'united-arab-emirates',
#    'NewConfirmed': 1041,
#    'TotalConfirmed': 98801,
#    'NewDeaths': 0,
#    'TotalDeaths': 426,
#    'NewRecovered': 1001,
#    'TotalRecovered': 88123,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'United Kingdom',
#    'CountryCode': 'GB',
#    'Slug': 'united-kingdom',
#    'NewConfirmed': 22965,
#    'TotalConfirmed': 505619,
#    'NewDeaths': 33,
#    'TotalDeaths': 42440,
#    'NewRecovered': 7,
#    'TotalRecovered': 2403,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'United States of America',
#    'CountryCode': 'US',
#    'Slug': 'united-states',
#    'NewConfirmed': 35504,
#    'TotalConfirmed': 7417845,
#    'NewDeaths': 337,
#    'TotalDeaths': 209721,
#    'NewRecovered': 14377,
#    'TotalRecovered': 2911699,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Uruguay',
#    'CountryCode': 'UY',
#    'Slug': 'uruguay',
#    'NewConfirmed': 23,
#    'TotalConfirmed': 2145,
#    'NewDeaths': 0,
#    'TotalDeaths': 48,
#    'NewRecovered': 13,
#    'TotalRecovered': 1844,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Uzbekistan',
#    'CountryCode': 'UZ',
#    'Slug': 'uzbekistan',
#    'NewConfirmed': 374,
#    'TotalConfirmed': 58612,
#    'NewDeaths': 3,
#    'TotalDeaths': 480,
#    'NewRecovered': 427,
#    'TotalRecovered': 55281,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Venezuela (Bolivarian Republic)',
#    'CountryCode': 'VE',
#    'Slug': 'venezuela',
#    'NewConfirmed': 788,
#    'TotalConfirmed': 78434,
#    'NewDeaths': 4,
#    'TotalDeaths': 653,
#    'NewRecovered': 819,
#    'TotalRecovered': 68917,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Viet Nam',
#    'CountryCode': 'VN',
#    'Slug': 'vietnam',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 1096,
#    'NewDeaths': 0,
#    'TotalDeaths': 35,
#    'NewRecovered': 0,
#    'TotalRecovered': 1020,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Western Sahara',
#    'CountryCode': 'EH',
#    'Slug': 'western-sahara',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 10,
#    'NewDeaths': 0,
#    'TotalDeaths': 1,
#    'NewRecovered': 0,
#    'TotalRecovered': 8,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Yemen',
#    'CountryCode': 'YE',
#    'Slug': 'yemen',
#    'NewConfirmed': 0,
#    'TotalConfirmed': 2041,
#    'NewDeaths': 2,
#    'TotalDeaths': 591,
#    'NewRecovered': 0,
#    'TotalRecovered': 1320,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Zambia',
#    'CountryCode': 'ZM',
#    'Slug': 'zambia',
#    'NewConfirmed': 78,
#    'TotalConfirmed': 15052,
#    'NewDeaths': 0,
#    'TotalDeaths': 333,
#    'NewRecovered': 93,
#    'TotalRecovered': 14187,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}},
#   {'Country': 'Zimbabwe',
#    'CountryCode': 'ZW',
#    'Slug': 'zimbabwe',
#    'NewConfirmed': 3,
#    'TotalConfirmed': 7888,
#    'NewDeaths': 0,
#    'TotalDeaths': 228,
#    'NewRecovered': 32,
#    'TotalRecovered': 6359,
#    'Date': '2020-10-06T02:49:09Z',
#    'Premium': {}}],
#  'Date': '2020-10-06T02:49:09Z'}

# %%
countries = summary["Countries"]
countries
# Out:
# [{'Country': 'Afghanistan',
#   'CountryCode': 'AF',
#   'Slug': 'afghanistan',
#   'NewConfirmed': 44,
#   'TotalConfirmed': 39341,
#   'NewDeaths': 0,
#   'TotalDeaths': 1462,
#   'NewRecovered': 10,
#   'TotalRecovered': 32852,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Albania',
#   'CountryCode': 'AL',
#   'Slug': 'albania',
#   'NewConfirmed': 149,
#   'TotalConfirmed': 14266,
#   'NewDeaths': 4,
#   'TotalDeaths': 396,
#   'NewRecovered': 139,
#   'TotalRecovered': 8675,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Algeria',
#   'CountryCode': 'DZ',
#   'Slug': 'algeria',
#   'NewConfirmed': 141,
#   'TotalConfirmed': 52136,
#   'NewDeaths': 4,
#   'TotalDeaths': 1760,
#   'NewRecovered': 96,
#   'TotalRecovered': 36578,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Andorra',
#   'CountryCode': 'AD',
#   'Slug': 'andorra',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 2110,
#   'NewDeaths': 0,
#   'TotalDeaths': 53,
#   'NewRecovered': 0,
#   'TotalRecovered': 1540,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Angola',
#   'CountryCode': 'AO',
#   'Slug': 'angola',
#   'NewConfirmed': 32,
#   'TotalConfirmed': 5402,
#   'NewDeaths': 2,
#   'TotalDeaths': 195,
#   'NewRecovered': 141,
#   'TotalRecovered': 2577,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Antigua and Barbuda',
#   'CountryCode': 'AG',
#   'Slug': 'antigua-and-barbuda',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 107,
#   'NewDeaths': 0,
#   'TotalDeaths': 3,
#   'NewRecovered': 0,
#   'TotalRecovered': 96,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Argentina',
#   'CountryCode': 'AR',
#   'Slug': 'argentina',
#   'NewConfirmed': 7668,
#   'TotalConfirmed': 798486,
#   'NewDeaths': 223,
#   'TotalDeaths': 21018,
#   'NewRecovered': 10558,
#   'TotalRecovered': 636672,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Armenia',
#   'CountryCode': 'AM',
#   'Slug': 'armenia',
#   'NewConfirmed': 571,
#   'TotalConfirmed': 52496,
#   'NewDeaths': 5,
#   'TotalDeaths': 977,
#   'NewRecovered': 89,
#   'TotalRecovered': 44672,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Australia',
#   'CountryCode': 'AU',
#   'Slug': 'australia',
#   'NewConfirmed': 13,
#   'TotalConfirmed': 27148,
#   'NewDeaths': 0,
#   'TotalDeaths': 894,
#   'NewRecovered': 24,
#   'TotalRecovered': 24888,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Austria',
#   'CountryCode': 'AT',
#   'Slug': 'austria',
#   'NewConfirmed': 714,
#   'TotalConfirmed': 48146,
#   'NewDeaths': 4,
#   'TotalDeaths': 813,
#   'NewRecovered': 584,
#   'TotalRecovered': 38629,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Azerbaijan',
#   'CountryCode': 'AZ',
#   'Slug': 'azerbaijan',
#   'NewConfirmed': 130,
#   'TotalConfirmed': 40691,
#   'NewDeaths': 1,
#   'TotalDeaths': 596,
#   'NewRecovered': 142,
#   'TotalRecovered': 38496,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Bahamas',
#   'CountryCode': 'BS',
#   'Slug': 'bahamas',
#   'NewConfirmed': 77,
#   'TotalConfirmed': 4409,
#   'NewDeaths': 0,
#   'TotalDeaths': 96,
#   'NewRecovered': 0,
#   'TotalRecovered': 2375,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Bahrain',
#   'CountryCode': 'BH',
#   'Slug': 'bahrain',
#   'NewConfirmed': 352,
#   'TotalConfirmed': 72662,
#   'NewDeaths': 2,
#   'TotalDeaths': 260,
#   'NewRecovered': 662,
#   'TotalRecovered': 67475,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Bangladesh',
#   'CountryCode': 'BD',
#   'Slug': 'bangladesh',
#   'NewConfirmed': 1125,
#   'TotalConfirmed': 368690,
#   'NewDeaths': 23,
#   'TotalDeaths': 5348,
#   'NewRecovered': 1587,
#   'TotalRecovered': 281656,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Barbados',
#   'CountryCode': 'BB',
#   'Slug': 'barbados',
#   'NewConfirmed': 3,
#   'TotalConfirmed': 199,
#   'NewDeaths': 0,
#   'TotalDeaths': 7,
#   'NewRecovered': 0,
#   'TotalRecovered': 182,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Belarus',
#   'CountryCode': 'BY',
#   'Slug': 'belarus',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 79852,
#   'NewDeaths': 0,
#   'TotalDeaths': 851,
#   'NewRecovered': 0,
#   'TotalRecovered': 75148,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Belgium',
#   'CountryCode': 'BE',
#   'Slug': 'belgium',
#   'NewConfirmed': 2612,
#   'TotalConfirmed': 130235,
#   'NewDeaths': 20,
#   'TotalDeaths': 10064,
#   'NewRecovered': 34,
#   'TotalRecovered': 19679,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Belize',
#   'CountryCode': 'BZ',
#   'Slug': 'belize',
#   'NewConfirmed': 51,
#   'TotalConfirmed': 2131,
#   'NewDeaths': 1,
#   'TotalDeaths': 29,
#   'NewRecovered': 56,
#   'TotalRecovered': 1346,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Benin',
#   'CountryCode': 'BJ',
#   'Slug': 'benin',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 2357,
#   'NewDeaths': 0,
#   'TotalDeaths': 41,
#   'NewRecovered': 0,
#   'TotalRecovered': 1973,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Bhutan',
#   'CountryCode': 'BT',
#   'Slug': 'bhutan',
#   'NewConfirmed': 15,
#   'TotalConfirmed': 298,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 7,
#   'TotalRecovered': 237,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Bolivia',
#   'CountryCode': 'BO',
#   'Slug': 'bolivia',
#   'NewConfirmed': 299,
#   'TotalConfirmed': 136868,
#   'NewDeaths': 28,
#   'TotalDeaths': 8101,
#   'NewRecovered': 442,
#   'TotalRecovered': 97547,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Bosnia and Herzegovina',
#   'CountryCode': 'BA',
#   'Slug': 'bosnia-and-herzegovina',
#   'NewConfirmed': 379,
#   'TotalConfirmed': 28354,
#   'NewDeaths': 8,
#   'TotalDeaths': 879,
#   'NewRecovered': 751,
#   'TotalRecovered': 21859,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Botswana',
#   'CountryCode': 'BW',
#   'Slug': 'botswana',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 3172,
#   'NewDeaths': 0,
#   'TotalDeaths': 16,
#   'NewRecovered': 0,
#   'TotalRecovered': 710,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Brazil',
#   'CountryCode': 'BR',
#   'Slug': 'brazil',
#   'NewConfirmed': 8456,
#   'TotalConfirmed': 4915289,
#   'NewDeaths': 365,
#   'TotalDeaths': 146352,
#   'NewRecovered': 14246,
#   'TotalRecovered': 4375354,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Brunei Darussalam',
#   'CountryCode': 'BN',
#   'Slug': 'brunei',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 146,
#   'NewDeaths': 0,
#   'TotalDeaths': 3,
#   'NewRecovered': 0,
#   'TotalRecovered': 142,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Bulgaria',
#   'CountryCode': 'BG',
#   'Slug': 'bulgaria',
#   'NewConfirmed': 69,
#   'TotalConfirmed': 21587,
#   'NewDeaths': 3,
#   'TotalDeaths': 844,
#   'NewRecovered': 30,
#   'TotalRecovered': 15014,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Burkina Faso',
#   'CountryCode': 'BF',
#   'Slug': 'burkina-faso',
#   'NewConfirmed': 13,
#   'TotalConfirmed': 2167,
#   'NewDeaths': 0,
#   'TotalDeaths': 59,
#   'NewRecovered': 22,
#   'TotalRecovered': 1419,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Burundi',
#   'CountryCode': 'BI',
#   'Slug': 'burundi',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 513,
#   'NewDeaths': 0,
#   'TotalDeaths': 1,
#   'NewRecovered': 0,
#   'TotalRecovered': 472,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Cambodia',
#   'CountryCode': 'KH',
#   'Slug': 'cambodia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 278,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 275,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Cameroon',
#   'CountryCode': 'CM',
#   'Slug': 'cameroon',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 20924,
#   'NewDeaths': 0,
#   'TotalDeaths': 420,
#   'NewRecovered': 0,
#   'TotalRecovered': 19764,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Canada',
#   'CountryCode': 'CA',
#   'Slug': 'canada',
#   'NewConfirmed': 2141,
#   'TotalConfirmed': 168488,
#   'NewDeaths': 45,
#   'TotalDeaths': 9532,
#   'NewRecovered': 1791,
#   'TotalRecovered': 142502,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Cape Verde',
#   'CountryCode': 'CV',
#   'Slug': 'cape-verde',
#   'NewConfirmed': 64,
#   'TotalConfirmed': 6360,
#   'NewDeaths': 3,
#   'TotalDeaths': 65,
#   'NewRecovered': 7,
#   'TotalRecovered': 5416,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Central African Republic',
#   'CountryCode': 'CF',
#   'Slug': 'central-african-republic',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 4845,
#   'NewDeaths': 0,
#   'TotalDeaths': 62,
#   'NewRecovered': 0,
#   'TotalRecovered': 1914,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Chad',
#   'CountryCode': 'TD',
#   'Slug': 'chad',
#   'NewConfirmed': 3,
#   'TotalConfirmed': 1217,
#   'NewDeaths': 1,
#   'TotalDeaths': 86,
#   'NewRecovered': 0,
#   'TotalRecovered': 1075,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Chile',
#   'CountryCode': 'CL',
#   'Slug': 'chile',
#   'NewConfirmed': 1708,
#   'TotalConfirmed': 470179,
#   'NewDeaths': 60,
#   'TotalDeaths': 12979,
#   'NewRecovered': 1189,
#   'TotalRecovered': 442070,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'China',
#   'CountryCode': 'CN',
#   'Slug': 'china',
#   'NewConfirmed': 25,
#   'TotalConfirmed': 90629,
#   'NewDeaths': 0,
#   'TotalDeaths': 4739,
#   'NewRecovered': 19,
#   'TotalRecovered': 85530,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Colombia',
#   'CountryCode': 'CO',
#   'Slug': 'colombia',
#   'NewConfirmed': 6905,
#   'TotalConfirmed': 855052,
#   'NewDeaths': 156,
#   'TotalDeaths': 26712,
#   'NewRecovered': 3873,
#   'TotalRecovered': 761674,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Comoros',
#   'CountryCode': 'KM',
#   'Slug': 'comoros',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 487,
#   'NewDeaths': 0,
#   'TotalDeaths': 7,
#   'NewRecovered': 0,
#   'TotalRecovered': 466,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Congo (Brazzaville)',
#   'CountryCode': 'CG',
#   'Slug': 'congo-brazzaville',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 5089,
#   'NewDeaths': 0,
#   'TotalDeaths': 89,
#   'NewRecovered': 0,
#   'TotalRecovered': 3887,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Congo (Kinshasa)',
#   'CountryCode': 'CD',
#   'Slug': 'congo-kinshasa',
#   'NewConfirmed': 8,
#   'TotalConfirmed': 10760,
#   'NewDeaths': 0,
#   'TotalDeaths': 274,
#   'NewRecovered': 27,
#   'TotalRecovered': 10239,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Costa Rica',
#   'CountryCode': 'CR',
#   'Slug': 'costa-rica',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 79182,
#   'NewDeaths': 0,
#   'TotalDeaths': 950,
#   'NewRecovered': 0,
#   'TotalRecovered': 45007,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Croatia',
#   'CountryCode': 'HR',
#   'Slug': 'croatia',
#   'NewConfirmed': 258,
#   'TotalConfirmed': 17659,
#   'NewDeaths': 5,
#   'TotalDeaths': 298,
#   'NewRecovered': 188,
#   'TotalRecovered': 15849,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Cuba',
#   'CountryCode': 'CU',
#   'Slug': 'cuba',
#   'NewConfirmed': 29,
#   'TotalConfirmed': 5809,
#   'NewDeaths': 0,
#   'TotalDeaths': 122,
#   'NewRecovered': 27,
#   'TotalRecovered': 5145,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Cyprus',
#   'CountryCode': 'CY',
#   'Slug': 'cyprus',
#   'NewConfirmed': 13,
#   'TotalConfirmed': 1824,
#   'NewDeaths': 0,
#   'TotalDeaths': 22,
#   'NewRecovered': 0,
#   'TotalRecovered': 1369,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Czech Republic',
#   'CountryCode': 'CZ',
#   'Slug': 'czech-republic',
#   'NewConfirmed': 1841,
#   'TotalConfirmed': 82446,
#   'NewDeaths': 16,
#   'TotalDeaths': 727,
#   'NewRecovered': 5076,
#   'TotalRecovered': 44149,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': "Côte d'Ivoire",
#   'CountryCode': 'CI',
#   'Slug': 'cote-divoire',
#   'NewConfirmed': 33,
#   'TotalConfirmed': 19882,
#   'NewDeaths': 0,
#   'TotalDeaths': 120,
#   'NewRecovered': 28,
#   'TotalRecovered': 19449,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Denmark',
#   'CountryCode': 'DK',
#   'Slug': 'denmark',
#   'NewConfirmed': 379,
#   'TotalConfirmed': 30168,
#   'NewDeaths': 4,
#   'TotalDeaths': 658,
#   'NewRecovered': 422,
#   'TotalRecovered': 23165,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Djibouti',
#   'CountryCode': 'DJ',
#   'Slug': 'djibouti',
#   'NewConfirmed': 1,
#   'TotalConfirmed': 5419,
#   'NewDeaths': 0,
#   'TotalDeaths': 61,
#   'NewRecovered': 2,
#   'TotalRecovered': 5349,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Dominica',
#   'CountryCode': 'DM',
#   'Slug': 'dominica',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 31,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 24,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Dominican Republic',
#   'CountryCode': 'DO',
#   'Slug': 'dominican-republic',
#   'NewConfirmed': 554,
#   'TotalConfirmed': 114480,
#   'NewDeaths': 6,
#   'TotalDeaths': 2134,
#   'NewRecovered': 731,
#   'TotalRecovered': 90366,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Ecuador',
#   'CountryCode': 'EC',
#   'Slug': 'ecuador',
#   'NewConfirmed': 683,
#   'TotalConfirmed': 141034,
#   'NewDeaths': 50,
#   'TotalDeaths': 11647,
#   'NewRecovered': 8215,
#   'TotalRecovered': 120511,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Egypt',
#   'CountryCode': 'EG',
#   'Slug': 'egypt',
#   'NewConfirmed': 108,
#   'TotalConfirmed': 103683,
#   'NewDeaths': 11,
#   'TotalDeaths': 5981,
#   'NewRecovered': 81,
#   'TotalRecovered': 97355,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'El Salvador',
#   'CountryCode': 'SV',
#   'Slug': 'el-salvador',
#   'NewConfirmed': 92,
#   'TotalConfirmed': 29450,
#   'NewDeaths': 6,
#   'TotalDeaths': 863,
#   'NewRecovered': 121,
#   'TotalRecovered': 24296,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Equatorial Guinea',
#   'CountryCode': 'GQ',
#   'Slug': 'equatorial-guinea',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 5045,
#   'NewDeaths': 0,
#   'TotalDeaths': 83,
#   'NewRecovered': 0,
#   'TotalRecovered': 4879,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Eritrea',
#   'CountryCode': 'ER',
#   'Slug': 'eritrea',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 398,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 358,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Estonia',
#   'CountryCode': 'EE',
#   'Slug': 'estonia',
#   'NewConfirmed': 30,
#   'TotalConfirmed': 3607,
#   'NewDeaths': 0,
#   'TotalDeaths': 67,
#   'NewRecovered': 22,
#   'TotalRecovered': 2749,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Ethiopia',
#   'CountryCode': 'ET',
#   'Slug': 'ethiopia',
#   'NewConfirmed': 959,
#   'TotalConfirmed': 78819,
#   'NewDeaths': 8,
#   'TotalDeaths': 1222,
#   'NewRecovered': 735,
#   'TotalRecovered': 33060,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Fiji',
#   'CountryCode': 'FJ',
#   'Slug': 'fiji',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 32,
#   'NewDeaths': 0,
#   'TotalDeaths': 2,
#   'NewRecovered': 0,
#   'TotalRecovered': 28,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Finland',
#   'CountryCode': 'FI',
#   'Slug': 'finland',
#   'NewConfirmed': 147,
#   'TotalConfirmed': 10538,
#   'NewDeaths': 0,
#   'TotalDeaths': 345,
#   'NewRecovered': 0,
#   'TotalRecovered': 8100,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'France',
#   'CountryCode': 'FR',
#   'Slug': 'france',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 629509,
#   'NewDeaths': 0,
#   'TotalDeaths': 32171,
#   'NewRecovered': 0,
#   'TotalRecovered': 100281,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Gabon',
#   'CountryCode': 'GA',
#   'Slug': 'gabon',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 8797,
#   'NewDeaths': 0,
#   'TotalDeaths': 54,
#   'NewRecovered': 0,
#   'TotalRecovered': 8067,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Gambia',
#   'CountryCode': 'GM',
#   'Slug': 'gambia',
#   'NewConfirmed': 4,
#   'TotalConfirmed': 3594,
#   'NewDeaths': 0,
#   'TotalDeaths': 115,
#   'NewRecovered': 0,
#   'TotalRecovered': 2226,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Georgia',
#   'CountryCode': 'GE',
#   'Slug': 'georgia',
#   'NewConfirmed': 554,
#   'TotalConfirmed': 8118,
#   'NewDeaths': 2,
#   'TotalDeaths': 50,
#   'NewRecovered': 252,
#   'TotalRecovered': 4244,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Germany',
#   'CountryCode': 'DE',
#   'Slug': 'germany',
#   'NewConfirmed': 1546,
#   'TotalConfirmed': 301573,
#   'NewDeaths': 2,
#   'TotalDeaths': 9533,
#   'NewRecovered': 1086,
#   'TotalRecovered': 262002,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Ghana',
#   'CountryCode': 'GH',
#   'Slug': 'ghana',
#   'NewConfirmed': 26,
#   'TotalConfirmed': 46829,
#   'NewDeaths': 0,
#   'TotalDeaths': 303,
#   'NewRecovered': 54,
#   'TotalRecovered': 46060,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Greece',
#   'CountryCode': 'GR',
#   'Slug': 'greece',
#   'NewConfirmed': 229,
#   'TotalConfirmed': 19842,
#   'NewDeaths': 4,
#   'TotalDeaths': 409,
#   'NewRecovered': 0,
#   'TotalRecovered': 1347,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Grenada',
#   'CountryCode': 'GD',
#   'Slug': 'grenada',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 24,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 24,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Guatemala',
#   'CountryCode': 'GT',
#   'Slug': 'guatemala',
#   'NewConfirmed': 215,
#   'TotalConfirmed': 93963,
#   'NewDeaths': 8,
#   'TotalDeaths': 3293,
#   'NewRecovered': 414,
#   'TotalRecovered': 82454,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Guinea',
#   'CountryCode': 'GN',
#   'Slug': 'guinea',
#   'NewConfirmed': 19,
#   'TotalConfirmed': 10754,
#   'NewDeaths': 0,
#   'TotalDeaths': 66,
#   'NewRecovered': 32,
#   'TotalRecovered': 10098,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Guinea-Bissau',
#   'CountryCode': 'GW',
#   'Slug': 'guinea-bissau',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 2362,
#   'NewDeaths': 0,
#   'TotalDeaths': 39,
#   'NewRecovered': 0,
#   'TotalRecovered': 1549,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Guyana',
#   'CountryCode': 'GY',
#   'Slug': 'guyana',
#   'NewConfirmed': 125,
#   'TotalConfirmed': 3093,
#   'NewDeaths': 2,
#   'TotalDeaths': 87,
#   'NewRecovered': 144,
#   'TotalRecovered': 1920,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Haiti',
#   'CountryCode': 'HT',
#   'Slug': 'haiti',
#   'NewConfirmed': 8,
#   'TotalConfirmed': 8819,
#   'NewDeaths': 0,
#   'TotalDeaths': 229,
#   'NewRecovered': 43,
#   'TotalRecovered': 6992,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Holy See (Vatican City State)',
#   'CountryCode': 'VA',
#   'Slug': 'holy-see-vatican-city-state',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 12,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 12,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Honduras',
#   'CountryCode': 'HN',
#   'Slug': 'honduras',
#   'NewConfirmed': 841,
#   'TotalConfirmed': 79629,
#   'NewDeaths': 23,
#   'TotalDeaths': 2422,
#   'NewRecovered': 118,
#   'TotalRecovered': 29305,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Hungary',
#   'CountryCode': 'HU',
#   'Slug': 'hungary',
#   'NewConfirmed': 858,
#   'TotalConfirmed': 30575,
#   'NewDeaths': 10,
#   'TotalDeaths': 822,
#   'NewRecovered': 646,
#   'TotalRecovered': 7470,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Iceland',
#   'CountryCode': 'IS',
#   'Slug': 'iceland',
#   'NewConfirmed': 49,
#   'TotalConfirmed': 2921,
#   'NewDeaths': 0,
#   'TotalDeaths': 10,
#   'NewRecovered': 65,
#   'TotalRecovered': 2277,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'India',
#   'CountryCode': 'IN',
#   'Slug': 'india',
#   'NewConfirmed': 74442,
#   'TotalConfirmed': 6623815,
#   'NewDeaths': 903,
#   'TotalDeaths': 102685,
#   'NewRecovered': 76737,
#   'TotalRecovered': 5586703,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Indonesia',
#   'CountryCode': 'ID',
#   'Slug': 'indonesia',
#   'NewConfirmed': 3992,
#   'TotalConfirmed': 303498,
#   'NewDeaths': 96,
#   'TotalDeaths': 11151,
#   'NewRecovered': 3401,
#   'TotalRecovered': 228453,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Iran, Islamic Republic of',
#   'CountryCode': 'IR',
#   'Slug': 'iran',
#   'NewConfirmed': 3653,
#   'TotalConfirmed': 471772,
#   'NewDeaths': 211,
#   'TotalDeaths': 26957,
#   'NewRecovered': 2291,
#   'TotalRecovered': 389966,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Iraq',
#   'CountryCode': 'IQ',
#   'Slug': 'iraq',
#   'NewConfirmed': 3210,
#   'TotalConfirmed': 379141,
#   'NewDeaths': 52,
#   'TotalDeaths': 9399,
#   'NewRecovered': 3817,
#   'TotalRecovered': 307482,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Ireland',
#   'CountryCode': 'IE',
#   'Slug': 'ireland',
#   'NewConfirmed': 364,
#   'TotalConfirmed': 38032,
#   'NewDeaths': 0,
#   'TotalDeaths': 1810,
#   'NewRecovered': 0,
#   'TotalRecovered': 23364,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Israel',
#   'CountryCode': 'IL',
#   'Slug': 'israel',
#   'NewConfirmed': 2332,
#   'TotalConfirmed': 266775,
#   'NewDeaths': 37,
#   'TotalDeaths': 1719,
#   'NewRecovered': 4378,
#   'TotalRecovered': 195629,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Italy',
#   'CountryCode': 'IT',
#   'Slug': 'italy',
#   'NewConfirmed': 2578,
#   'TotalConfirmed': 325329,
#   'NewDeaths': 18,
#   'TotalDeaths': 35986,
#   'NewRecovered': 697,
#   'TotalRecovered': 231914,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Jamaica',
#   'CountryCode': 'JM',
#   'Slug': 'jamaica',
#   'NewConfirmed': 100,
#   'TotalConfirmed': 6895,
#   'NewDeaths': 1,
#   'TotalDeaths': 120,
#   'NewRecovered': 115,
#   'TotalRecovered': 2460,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Japan',
#   'CountryCode': 'JP',
#   'Slug': 'japan',
#   'NewConfirmed': 401,
#   'TotalConfirmed': 85746,
#   'NewDeaths': 4,
#   'TotalDeaths': 1598,
#   'NewRecovered': 1151,
#   'TotalRecovered': 77851,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Jordan',
#   'CountryCode': 'JO',
#   'Slug': 'jordan',
#   'NewConfirmed': 891,
#   'TotalConfirmed': 15640,
#   'NewDeaths': 13,
#   'TotalDeaths': 101,
#   'NewRecovered': 139,
#   'TotalRecovered': 5240,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Kazakhstan',
#   'CountryCode': 'KZ',
#   'Slug': 'kazakhstan',
#   'NewConfirmed': 59,
#   'TotalConfirmed': 108236,
#   'NewDeaths': 0,
#   'TotalDeaths': 1725,
#   'NewRecovered': 72,
#   'TotalRecovered': 103277,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Kenya',
#   'CountryCode': 'KE',
#   'Slug': 'kenya',
#   'NewConfirmed': 243,
#   'TotalConfirmed': 39427,
#   'NewDeaths': 3,
#   'TotalDeaths': 731,
#   'NewRecovered': 233,
#   'TotalRecovered': 25659,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Korea (South)',
#   'CountryCode': 'KR',
#   'Slug': 'korea-south',
#   'NewConfirmed': 73,
#   'TotalConfirmed': 24164,
#   'NewDeaths': 1,
#   'TotalDeaths': 422,
#   'NewRecovered': 41,
#   'TotalRecovered': 21886,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Kuwait',
#   'CountryCode': 'KW',
#   'Slug': 'kuwait',
#   'NewConfirmed': 567,
#   'TotalConfirmed': 107025,
#   'NewDeaths': 4,
#   'TotalDeaths': 624,
#   'NewRecovered': 605,
#   'TotalRecovered': 99040,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Kyrgyzstan',
#   'CountryCode': 'KG',
#   'Slug': 'kyrgyzstan',
#   'NewConfirmed': 244,
#   'TotalConfirmed': 47428,
#   'NewDeaths': 0,
#   'TotalDeaths': 1066,
#   'NewRecovered': 140,
#   'TotalRecovered': 43418,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Lao PDR',
#   'CountryCode': 'LA',
#   'Slug': 'lao-pdr',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 23,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 22,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Latvia',
#   'CountryCode': 'LV',
#   'Slug': 'latvia',
#   'NewConfirmed': 67,
#   'TotalConfirmed': 2086,
#   'NewDeaths': 0,
#   'TotalDeaths': 38,
#   'NewRecovered': 0,
#   'TotalRecovered': 1307,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Lebanon',
#   'CountryCode': 'LB',
#   'Slug': 'lebanon',
#   'NewConfirmed': 988,
#   'TotalConfirmed': 44482,
#   'NewDeaths': 8,
#   'TotalDeaths': 406,
#   'NewRecovered': 523,
#   'TotalRecovered': 19782,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Lesotho',
#   'CountryCode': 'LS',
#   'Slug': 'lesotho',
#   'NewConfirmed': 3,
#   'TotalConfirmed': 1683,
#   'NewDeaths': 0,
#   'TotalDeaths': 39,
#   'NewRecovered': 0,
#   'TotalRecovered': 926,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Liberia',
#   'CountryCode': 'LR',
#   'Slug': 'liberia',
#   'NewConfirmed': 1,
#   'TotalConfirmed': 1348,
#   'NewDeaths': 0,
#   'TotalDeaths': 82,
#   'NewRecovered': 15,
#   'TotalRecovered': 1236,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Libya',
#   'CountryCode': 'LY',
#   'Slug': 'libya',
#   'NewConfirmed': 722,
#   'TotalConfirmed': 36809,
#   'NewDeaths': 14,
#   'TotalDeaths': 592,
#   'NewRecovered': 540,
#   'TotalRecovered': 21429,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Liechtenstein',
#   'CountryCode': 'LI',
#   'Slug': 'liechtenstein',
#   'NewConfirmed': 3,
#   'TotalConfirmed': 126,
#   'NewDeaths': 0,
#   'TotalDeaths': 1,
#   'NewRecovered': 0,
#   'TotalRecovered': 116,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Lithuania',
#   'CountryCode': 'LT',
#   'Slug': 'lithuania',
#   'NewConfirmed': 104,
#   'TotalConfirmed': 5185,
#   'NewDeaths': 0,
#   'TotalDeaths': 94,
#   'NewRecovered': 1,
#   'TotalRecovered': 2495,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Luxembourg',
#   'CountryCode': 'LU',
#   'Slug': 'luxembourg',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 8709,
#   'NewDeaths': 0,
#   'TotalDeaths': 125,
#   'NewRecovered': 0,
#   'TotalRecovered': 7428,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Macao, SAR China',
#   'CountryCode': 'MO',
#   'Slug': 'macao-sar-china',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 0,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Macedonia, Republic of',
#   'CountryCode': 'MK',
#   'Slug': 'macedonia',
#   'NewConfirmed': 188,
#   'TotalConfirmed': 18790,
#   'NewDeaths': 3,
#   'TotalDeaths': 756,
#   'NewRecovered': 77,
#   'TotalRecovered': 15341,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Madagascar',
#   'CountryCode': 'MG',
#   'Slug': 'madagascar',
#   'NewConfirmed': 29,
#   'TotalConfirmed': 16558,
#   'NewDeaths': 0,
#   'TotalDeaths': 232,
#   'NewRecovered': 6,
#   'TotalRecovered': 15486,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Malawi',
#   'CountryCode': 'MW',
#   'Slug': 'malawi',
#   'NewConfirmed': 3,
#   'TotalConfirmed': 5786,
#   'NewDeaths': 0,
#   'TotalDeaths': 179,
#   'NewRecovered': 2,
#   'TotalRecovered': 4541,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Malaysia',
#   'CountryCode': 'MY',
#   'Slug': 'malaysia',
#   'NewConfirmed': 293,
#   'TotalConfirmed': 12381,
#   'NewDeaths': 0,
#   'TotalDeaths': 137,
#   'NewRecovered': 67,
#   'TotalRecovered': 10283,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Maldives',
#   'CountryCode': 'MV',
#   'Slug': 'maldives',
#   'NewConfirmed': 65,
#   'TotalConfirmed': 10530,
#   'NewDeaths': 0,
#   'TotalDeaths': 34,
#   'NewRecovered': 54,
#   'TotalRecovered': 9364,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Mali',
#   'CountryCode': 'ML',
#   'Slug': 'mali',
#   'NewConfirmed': 14,
#   'TotalConfirmed': 3184,
#   'NewDeaths': 0,
#   'TotalDeaths': 131,
#   'NewRecovered': 3,
#   'TotalRecovered': 2479,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Malta',
#   'CountryCode': 'MT',
#   'Slug': 'malta',
#   'NewConfirmed': 66,
#   'TotalConfirmed': 3270,
#   'NewDeaths': 1,
#   'TotalDeaths': 39,
#   'NewRecovered': 47,
#   'TotalRecovered': 2758,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Mauritania',
#   'CountryCode': 'MR',
#   'Slug': 'mauritania',
#   'NewConfirmed': 3,
#   'TotalConfirmed': 7520,
#   'NewDeaths': 0,
#   'TotalDeaths': 162,
#   'NewRecovered': 14,
#   'TotalRecovered': 7188,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Mauritius',
#   'CountryCode': 'MU',
#   'Slug': 'mauritius',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 385,
#   'NewDeaths': 0,
#   'TotalDeaths': 10,
#   'NewRecovered': 0,
#   'TotalRecovered': 357,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Mexico',
#   'CountryCode': 'MX',
#   'Slug': 'mexico',
#   'NewConfirmed': 3712,
#   'TotalConfirmed': 761665,
#   'NewDeaths': 208,
#   'TotalDeaths': 79088,
#   'NewRecovered': 7130,
#   'TotalRecovered': 645123,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Moldova',
#   'CountryCode': 'MD',
#   'Slug': 'moldova',
#   'NewConfirmed': 691,
#   'TotalConfirmed': 56579,
#   'NewDeaths': 13,
#   'TotalDeaths': 1366,
#   'NewRecovered': 480,
#   'TotalRecovered': 40955,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Monaco',
#   'CountryCode': 'MC',
#   'Slug': 'monaco',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 222,
#   'NewDeaths': 0,
#   'TotalDeaths': 2,
#   'NewRecovered': 1,
#   'TotalRecovered': 189,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Mongolia',
#   'CountryCode': 'MN',
#   'Slug': 'mongolia',
#   'NewConfirmed': 1,
#   'TotalConfirmed': 314,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 307,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Montenegro',
#   'CountryCode': 'ME',
#   'Slug': 'montenegro',
#   'NewConfirmed': 193,
#   'TotalConfirmed': 12127,
#   'NewDeaths': 5,
#   'TotalDeaths': 179,
#   'NewRecovered': 150,
#   'TotalRecovered': 7953,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Morocco',
#   'CountryCode': 'MA',
#   'Slug': 'morocco',
#   'NewConfirmed': 2044,
#   'TotalConfirmed': 133272,
#   'NewDeaths': 37,
#   'TotalDeaths': 2330,
#   'NewRecovered': 2349,
#   'TotalRecovered': 111036,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Mozambique',
#   'CountryCode': 'MZ',
#   'Slug': 'mozambique',
#   'NewConfirmed': 147,
#   'TotalConfirmed': 9196,
#   'NewDeaths': 2,
#   'TotalDeaths': 66,
#   'NewRecovered': 116,
#   'TotalRecovered': 5852,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Myanmar',
#   'CountryCode': 'MM',
#   'Slug': 'myanmar',
#   'NewConfirmed': 1291,
#   'TotalConfirmed': 17794,
#   'NewDeaths': 41,
#   'TotalDeaths': 412,
#   'NewRecovered': 400,
#   'TotalRecovered': 5195,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Namibia',
#   'CountryCode': 'NA',
#   'Slug': 'namibia',
#   'NewConfirmed': 54,
#   'TotalConfirmed': 11626,
#   'NewDeaths': 0,
#   'TotalDeaths': 123,
#   'NewRecovered': 10,
#   'TotalRecovered': 9429,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Nepal',
#   'CountryCode': 'NP',
#   'Slug': 'nepal',
#   'NewConfirmed': 2253,
#   'TotalConfirmed': 86823,
#   'NewDeaths': 7,
#   'TotalDeaths': 535,
#   'NewRecovered': 1329,
#   'TotalRecovered': 64069,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Netherlands',
#   'CountryCode': 'NL',
#   'Slug': 'netherlands',
#   'NewConfirmed': 4003,
#   'TotalConfirmed': 135892,
#   'NewDeaths': 5,
#   'TotalDeaths': 6454,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'New Zealand',
#   'CountryCode': 'NZ',
#   'Slug': 'new-zealand',
#   'NewConfirmed': 1,
#   'TotalConfirmed': 1855,
#   'NewDeaths': 0,
#   'TotalDeaths': 25,
#   'NewRecovered': 2,
#   'TotalRecovered': 1790,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Nicaragua',
#   'CountryCode': 'NI',
#   'Slug': 'nicaragua',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 5170,
#   'NewDeaths': 0,
#   'TotalDeaths': 151,
#   'NewRecovered': 0,
#   'TotalRecovered': 2913,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Niger',
#   'CountryCode': 'NE',
#   'Slug': 'niger',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1200,
#   'NewDeaths': 0,
#   'TotalDeaths': 69,
#   'NewRecovered': 0,
#   'TotalRecovered': 1115,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Nigeria',
#   'CountryCode': 'NG',
#   'Slug': 'nigeria',
#   'NewConfirmed': 58,
#   'TotalConfirmed': 59345,
#   'NewDeaths': 0,
#   'TotalDeaths': 1113,
#   'NewRecovered': 50,
#   'TotalRecovered': 50768,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Norway',
#   'CountryCode': 'NO',
#   'Slug': 'norway',
#   'NewConfirmed': 95,
#   'TotalConfirmed': 14457,
#   'NewDeaths': 0,
#   'TotalDeaths': 275,
#   'NewRecovered': 0,
#   'TotalRecovered': 11190,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Oman',
#   'CountryCode': 'OM',
#   'Slug': 'oman',
#   'NewConfirmed': 2685,
#   'TotalConfirmed': 101270,
#   'NewDeaths': 42,
#   'TotalDeaths': 977,
#   'NewRecovered': 1768,
#   'TotalRecovered': 90296,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Pakistan',
#   'CountryCode': 'PK',
#   'Slug': 'pakistan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 314616,
#   'NewDeaths': 0,
#   'TotalDeaths': 6513,
#   'NewRecovered': 0,
#   'TotalRecovered': 298968,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Palestinian Territory',
#   'CountryCode': 'PS',
#   'Slug': 'palestine',
#   'NewConfirmed': 420,
#   'TotalConfirmed': 41498,
#   'NewDeaths': 1,
#   'TotalDeaths': 330,
#   'NewRecovered': 1256,
#   'TotalRecovered': 34698,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Panama',
#   'CountryCode': 'PA',
#   'Slug': 'panama',
#   'NewConfirmed': 633,
#   'TotalConfirmed': 115286,
#   'NewDeaths': 9,
#   'TotalDeaths': 2423,
#   'NewRecovered': 614,
#   'TotalRecovered': 91809,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Papua New Guinea',
#   'CountryCode': 'PG',
#   'Slug': 'papua-new-guinea',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 540,
#   'NewDeaths': 0,
#   'TotalDeaths': 7,
#   'NewRecovered': 0,
#   'TotalRecovered': 527,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Paraguay',
#   'CountryCode': 'PY',
#   'Slug': 'paraguay',
#   'NewConfirmed': 730,
#   'TotalConfirmed': 44182,
#   'NewDeaths': 16,
#   'TotalDeaths': 929,
#   'NewRecovered': 691,
#   'TotalRecovered': 27203,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Peru',
#   'CountryCode': 'PE',
#   'Slug': 'peru',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 821564,
#   'NewDeaths': 0,
#   'TotalDeaths': 32609,
#   'NewRecovered': 5223,
#   'TotalRecovered': 700868,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Philippines',
#   'CountryCode': 'PH',
#   'Slug': 'philippines',
#   'NewConfirmed': 3167,
#   'TotalConfirmed': 322497,
#   'NewDeaths': 98,
#   'TotalDeaths': 5776,
#   'NewRecovered': 18033,
#   'TotalRecovered': 273079,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Poland',
#   'CountryCode': 'PL',
#   'Slug': 'poland',
#   'NewConfirmed': 1934,
#   'TotalConfirmed': 100074,
#   'NewDeaths': 26,
#   'TotalDeaths': 2630,
#   'NewRecovered': 794,
#   'TotalRecovered': 73003,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Portugal',
#   'CountryCode': 'PT',
#   'Slug': 'portugal',
#   'NewConfirmed': 904,
#   'TotalConfirmed': 79151,
#   'NewDeaths': 10,
#   'TotalDeaths': 2005,
#   'NewRecovered': 362,
#   'TotalRecovered': 50207,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Qatar',
#   'CountryCode': 'QA',
#   'Slug': 'qatar',
#   'NewConfirmed': 159,
#   'TotalConfirmed': 126498,
#   'NewDeaths': 0,
#   'TotalDeaths': 216,
#   'NewRecovered': 173,
#   'TotalRecovered': 123475,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Republic of Kosovo',
#   'CountryCode': 'XK',
#   'Slug': 'kosovo',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 12683,
#   'NewDeaths': 0,
#   'TotalDeaths': 488,
#   'NewRecovered': 0,
#   'TotalRecovered': 8788,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Romania',
#   'CountryCode': 'RO',
#   'Slug': 'romania',
#   'NewConfirmed': 1835,
#   'TotalConfirmed': 135900,
#   'NewDeaths': 56,
#   'TotalDeaths': 5003,
#   'NewRecovered': 1077,
#   'TotalRecovered': 108135,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Russian Federation',
#   'CountryCode': 'RU',
#   'Slug': 'russia',
#   'NewConfirmed': 10376,
#   'TotalConfirmed': 1209039,
#   'NewDeaths': 107,
#   'TotalDeaths': 21260,
#   'NewRecovered': 3239,
#   'TotalRecovered': 975488,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Rwanda',
#   'CountryCode': 'RW',
#   'Slug': 'rwanda',
#   'NewConfirmed': 14,
#   'TotalConfirmed': 4866,
#   'NewDeaths': 0,
#   'TotalDeaths': 29,
#   'NewRecovered': 5,
#   'TotalRecovered': 3216,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Réunion',
#   'CountryCode': 'RE',
#   'Slug': 'réunion',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 0,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Saint Kitts and Nevis',
#   'CountryCode': 'KN',
#   'Slug': 'saint-kitts-and-nevis',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 19,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 17,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Saint Lucia',
#   'CountryCode': 'LC',
#   'Slug': 'saint-lucia',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 27,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 27,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Saint Vincent and Grenadines',
#   'CountryCode': 'VC',
#   'Slug': 'saint-vincent-and-the-grenadines',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 64,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 64,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'San Marino',
#   'CountryCode': 'SM',
#   'Slug': 'san-marino',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 732,
#   'NewDeaths': 0,
#   'TotalDeaths': 42,
#   'NewRecovered': 0,
#   'TotalRecovered': 680,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Sao Tome and Principe',
#   'CountryCode': 'ST',
#   'Slug': 'sao-tome-and-principe',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 913,
#   'NewDeaths': 0,
#   'TotalDeaths': 15,
#   'NewRecovered': 1,
#   'TotalRecovered': 887,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Saudi Arabia',
#   'CountryCode': 'SA',
#   'Slug': 'saudi-arabia',
#   'NewConfirmed': 390,
#   'TotalConfirmed': 336387,
#   'NewDeaths': 25,
#   'TotalDeaths': 4875,
#   'NewRecovered': 511,
#   'TotalRecovered': 321485,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Senegal',
#   'CountryCode': 'SN',
#   'Slug': 'senegal',
#   'NewConfirmed': 26,
#   'TotalConfirmed': 15094,
#   'NewDeaths': 0,
#   'TotalDeaths': 312,
#   'NewRecovered': 54,
#   'TotalRecovered': 12805,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Serbia',
#   'CountryCode': 'RS',
#   'Slug': 'serbia',
#   'NewConfirmed': 59,
#   'TotalConfirmed': 33901,
#   'NewDeaths': 1,
#   'TotalDeaths': 754,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Seychelles',
#   'CountryCode': 'SC',
#   'Slug': 'seychelles',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 146,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 143,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Sierra Leone',
#   'CountryCode': 'SL',
#   'Slug': 'sierra-leone',
#   'NewConfirmed': 10,
#   'TotalConfirmed': 2269,
#   'NewDeaths': 0,
#   'TotalDeaths': 72,
#   'NewRecovered': 2,
#   'TotalRecovered': 1706,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Singapore',
#   'CountryCode': 'SG',
#   'Slug': 'singapore',
#   'NewConfirmed': 12,
#   'TotalConfirmed': 57812,
#   'NewDeaths': 0,
#   'TotalDeaths': 27,
#   'NewRecovered': 13,
#   'TotalRecovered': 57575,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Slovakia',
#   'CountryCode': 'SK',
#   'Slug': 'slovakia',
#   'NewConfirmed': 818,
#   'TotalConfirmed': 13139,
#   'NewDeaths': 1,
#   'TotalDeaths': 55,
#   'NewRecovered': 35,
#   'TotalRecovered': 4828,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Slovenia',
#   'CountryCode': 'SI',
#   'Slug': 'slovenia',
#   'NewConfirmed': 168,
#   'TotalConfirmed': 6498,
#   'NewDeaths': 0,
#   'TotalDeaths': 155,
#   'NewRecovered': 224,
#   'TotalRecovered': 4265,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Somalia',
#   'CountryCode': 'SO',
#   'Slug': 'somalia',
#   'NewConfirmed': 152,
#   'TotalConfirmed': 3745,
#   'NewDeaths': 0,
#   'TotalDeaths': 99,
#   'NewRecovered': 9,
#   'TotalRecovered': 3010,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'South Africa',
#   'CountryCode': 'ZA',
#   'Slug': 'south-africa',
#   'NewConfirmed': 1573,
#   'TotalConfirmed': 681289,
#   'NewDeaths': 38,
#   'TotalDeaths': 16976,
#   'NewRecovered': 2018,
#   'TotalRecovered': 614781,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'South Sudan',
#   'CountryCode': 'SS',
#   'Slug': 'south-sudan',
#   'NewConfirmed': 11,
#   'TotalConfirmed': 2726,
#   'NewDeaths': 0,
#   'TotalDeaths': 50,
#   'NewRecovered': 0,
#   'TotalRecovered': 1290,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Spain',
#   'CountryCode': 'ES',
#   'Slug': 'spain',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 789932,
#   'NewDeaths': 0,
#   'TotalDeaths': 32086,
#   'NewRecovered': 0,
#   'TotalRecovered': 150376,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Sri Lanka',
#   'CountryCode': 'LK',
#   'Slug': 'sri-lanka',
#   'NewConfirmed': 7,
#   'TotalConfirmed': 3402,
#   'NewDeaths': 0,
#   'TotalDeaths': 13,
#   'NewRecovered': 4,
#   'TotalRecovered': 3258,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Sudan',
#   'CountryCode': 'SD',
#   'Slug': 'sudan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 13653,
#   'NewDeaths': 0,
#   'TotalDeaths': 836,
#   'NewRecovered': 0,
#   'TotalRecovered': 6764,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Suriname',
#   'CountryCode': 'SR',
#   'Slug': 'suriname',
#   'NewConfirmed': 17,
#   'TotalConfirmed': 4941,
#   'NewDeaths': 0,
#   'TotalDeaths': 106,
#   'NewRecovered': 18,
#   'TotalRecovered': 4741,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Swaziland',
#   'CountryCode': 'SZ',
#   'Slug': 'swaziland',
#   'NewConfirmed': 39,
#   'TotalConfirmed': 5569,
#   'NewDeaths': 0,
#   'TotalDeaths': 111,
#   'NewRecovered': 51,
#   'TotalRecovered': 5127,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Sweden',
#   'CountryCode': 'SE',
#   'Slug': 'sweden',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 94283,
#   'NewDeaths': 0,
#   'TotalDeaths': 5895,
#   'NewRecovered': 0,
#   'TotalRecovered': 0,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Switzerland',
#   'CountryCode': 'CH',
#   'Slug': 'switzerland',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 54384,
#   'NewDeaths': 1,
#   'TotalDeaths': 2077,
#   'NewRecovered': 0,
#   'TotalRecovered': 45800,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Syrian Arab Republic (Syria)',
#   'CountryCode': 'SY',
#   'Slug': 'syria',
#   'NewConfirmed': 37,
#   'TotalConfirmed': 4366,
#   'NewDeaths': 1,
#   'TotalDeaths': 205,
#   'NewRecovered': 12,
#   'TotalRecovered': 1155,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Taiwan, Republic of China',
#   'CountryCode': 'TW',
#   'Slug': 'taiwan',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 517,
#   'NewDeaths': 0,
#   'TotalDeaths': 7,
#   'NewRecovered': 0,
#   'TotalRecovered': 484,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Tajikistan',
#   'CountryCode': 'TJ',
#   'Slug': 'tajikistan',
#   'NewConfirmed': 40,
#   'TotalConfirmed': 9935,
#   'NewDeaths': 1,
#   'TotalDeaths': 78,
#   'NewRecovered': 42,
#   'TotalRecovered': 8749,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Tanzania, United Republic of',
#   'CountryCode': 'TZ',
#   'Slug': 'tanzania',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 509,
#   'NewDeaths': 0,
#   'TotalDeaths': 21,
#   'NewRecovered': 0,
#   'TotalRecovered': 183,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Thailand',
#   'CountryCode': 'TH',
#   'Slug': 'thailand',
#   'NewConfirmed': 5,
#   'TotalConfirmed': 3590,
#   'NewDeaths': 0,
#   'TotalDeaths': 59,
#   'NewRecovered': 2,
#   'TotalRecovered': 3390,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Timor-Leste',
#   'CountryCode': 'TL',
#   'Slug': 'timor-leste',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 28,
#   'NewDeaths': 0,
#   'TotalDeaths': 0,
#   'NewRecovered': 0,
#   'TotalRecovered': 28,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Togo',
#   'CountryCode': 'TG',
#   'Slug': 'togo',
#   'NewConfirmed': 14,
#   'TotalConfirmed': 1854,
#   'NewDeaths': 0,
#   'TotalDeaths': 48,
#   'NewRecovered': 17,
#   'TotalRecovered': 1392,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Trinidad and Tobago',
#   'CountryCode': 'TT',
#   'Slug': 'trinidad-and-tobago',
#   'NewConfirmed': 48,
#   'TotalConfirmed': 4763,
#   'NewDeaths': 2,
#   'TotalDeaths': 81,
#   'NewRecovered': 41,
#   'TotalRecovered': 2843,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Tunisia',
#   'CountryCode': 'TN',
#   'Slug': 'tunisia',
#   'NewConfirmed': 1286,
#   'TotalConfirmed': 22230,
#   'NewDeaths': 45,
#   'TotalDeaths': 321,
#   'NewRecovered': 0,
#   'TotalRecovered': 5032,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Turkey',
#   'CountryCode': 'TR',
#   'Slug': 'turkey',
#   'NewConfirmed': 1429,
#   'TotalConfirmed': 324443,
#   'NewDeaths': 57,
#   'TotalDeaths': 8441,
#   'NewRecovered': 1182,
#   'TotalRecovered': 285050,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Uganda',
#   'CountryCode': 'UG',
#   'Slug': 'uganda',
#   'NewConfirmed': 146,
#   'TotalConfirmed': 8808,
#   'NewDeaths': 2,
#   'TotalDeaths': 81,
#   'NewRecovered': 190,
#   'TotalRecovered': 4736,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Ukraine',
#   'CountryCode': 'UA',
#   'Slug': 'ukraine',
#   'NewConfirmed': 4263,
#   'TotalConfirmed': 232424,
#   'NewDeaths': 44,
#   'TotalDeaths': 4495,
#   'NewRecovered': 1415,
#   'TotalRecovered': 103762,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'United Arab Emirates',
#   'CountryCode': 'AE',
#   'Slug': 'united-arab-emirates',
#   'NewConfirmed': 1041,
#   'TotalConfirmed': 98801,
#   'NewDeaths': 0,
#   'TotalDeaths': 426,
#   'NewRecovered': 1001,
#   'TotalRecovered': 88123,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'United Kingdom',
#   'CountryCode': 'GB',
#   'Slug': 'united-kingdom',
#   'NewConfirmed': 22965,
#   'TotalConfirmed': 505619,
#   'NewDeaths': 33,
#   'TotalDeaths': 42440,
#   'NewRecovered': 7,
#   'TotalRecovered': 2403,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'United States of America',
#   'CountryCode': 'US',
#   'Slug': 'united-states',
#   'NewConfirmed': 35504,
#   'TotalConfirmed': 7417845,
#   'NewDeaths': 337,
#   'TotalDeaths': 209721,
#   'NewRecovered': 14377,
#   'TotalRecovered': 2911699,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Uruguay',
#   'CountryCode': 'UY',
#   'Slug': 'uruguay',
#   'NewConfirmed': 23,
#   'TotalConfirmed': 2145,
#   'NewDeaths': 0,
#   'TotalDeaths': 48,
#   'NewRecovered': 13,
#   'TotalRecovered': 1844,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Uzbekistan',
#   'CountryCode': 'UZ',
#   'Slug': 'uzbekistan',
#   'NewConfirmed': 374,
#   'TotalConfirmed': 58612,
#   'NewDeaths': 3,
#   'TotalDeaths': 480,
#   'NewRecovered': 427,
#   'TotalRecovered': 55281,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Venezuela (Bolivarian Republic)',
#   'CountryCode': 'VE',
#   'Slug': 'venezuela',
#   'NewConfirmed': 788,
#   'TotalConfirmed': 78434,
#   'NewDeaths': 4,
#   'TotalDeaths': 653,
#   'NewRecovered': 819,
#   'TotalRecovered': 68917,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Viet Nam',
#   'CountryCode': 'VN',
#   'Slug': 'vietnam',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 1096,
#   'NewDeaths': 0,
#   'TotalDeaths': 35,
#   'NewRecovered': 0,
#   'TotalRecovered': 1020,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Western Sahara',
#   'CountryCode': 'EH',
#   'Slug': 'western-sahara',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 10,
#   'NewDeaths': 0,
#   'TotalDeaths': 1,
#   'NewRecovered': 0,
#   'TotalRecovered': 8,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Yemen',
#   'CountryCode': 'YE',
#   'Slug': 'yemen',
#   'NewConfirmed': 0,
#   'TotalConfirmed': 2041,
#   'NewDeaths': 2,
#   'TotalDeaths': 591,
#   'NewRecovered': 0,
#   'TotalRecovered': 1320,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Zambia',
#   'CountryCode': 'ZM',
#   'Slug': 'zambia',
#   'NewConfirmed': 78,
#   'TotalConfirmed': 15052,
#   'NewDeaths': 0,
#   'TotalDeaths': 333,
#   'NewRecovered': 93,
#   'TotalRecovered': 14187,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}},
#  {'Country': 'Zimbabwe',
#   'CountryCode': 'ZW',
#   'Slug': 'zimbabwe',
#   'NewConfirmed': 3,
#   'TotalConfirmed': 7888,
#   'NewDeaths': 0,
#   'TotalDeaths': 228,
#   'NewRecovered': 32,
#   'TotalRecovered': 6359,
#   'Date': '2020-10-06T02:49:09Z',
#   'Premium': {}}]

# %%
countries_json = json.dumps(countries)
df = pd.read_json(countries_json)
print(df)
df
# Out:
#             Country CountryCode            Slug  NewConfirmed  TotalConfirmed  \
# 0       Afghanistan          AF     afghanistan            44           39341
# 1           Albania          AL         albania           149           14266
# 2           Algeria          DZ         algeria           141           52136
# 3           Andorra          AD         andorra             0            2110
# 4            Angola          AO          angola            32            5402
# ..              ...         ...             ...           ...             ...
# 183        Viet Nam          VN         vietnam             0            1096
# 184  Western Sahara          EH  western-sahara             0              10
# 185           Yemen          YE           yemen             0            2041
# 186          Zambia          ZM          zambia            78           15052
# 187        Zimbabwe          ZW        zimbabwe             3            7888
#
#      NewDeaths  TotalDeaths  NewRecovered  TotalRecovered  \
# 0            0         1462            10           32852
# 1            4          396           139            8675
# 2            4         1760            96           36578
# 3            0           53             0            1540
# 4            2          195           141            2577
# ..         ...          ...           ...             ...
# 183          0           35             0            1020
# 184          0            1             0               8
# 185          2          591             0            1320
# 186          0          333            93           14187
# 187          0          228            32            6359
#
#                          Date Premium
# 0   2020-10-06 02:49:09+00:00      {}
# 1   2020-10-06 02:49:09+00:00      {}
# 2   2020-10-06 02:49:09+00:00      {}
# 3   2020-10-06 02:49:09+00:00      {}
# 4   2020-10-06 02:49:09+00:00      {}
# ..                        ...     ...
# 183 2020-10-06 02:49:09+00:00      {}
# 184 2020-10-06 02:49:09+00:00      {}
# 185 2020-10-06 02:49:09+00:00      {}
# 186 2020-10-06 02:49:09+00:00      {}
# 187 2020-10-06 02:49:09+00:00      {}
#
# [188 rows x 11 columns]
#             Country CountryCode            Slug  NewConfirmed  TotalConfirmed  \
# 0       Afghanistan          AF     afghanistan            44           39341
# 1           Albania          AL         albania           149           14266
# 2           Algeria          DZ         algeria           141           52136
# 3           Andorra          AD         andorra             0            2110
# 4            Angola          AO          angola            32            5402
# ..              ...         ...             ...           ...             ...
# 183        Viet Nam          VN         vietnam             0            1096
# 184  Western Sahara          EH  western-sahara             0              10
# 185           Yemen          YE           yemen             0            2041
# 186          Zambia          ZM          zambia            78           15052
# 187        Zimbabwe          ZW        zimbabwe             3            7888
#
#      NewDeaths  TotalDeaths  NewRecovered  TotalRecovered  \
# 0            0         1462            10           32852
# 1            4          396           139            8675
# 2            4         1760            96           36578
# 3            0           53             0            1540
# 4            2          195           141            2577
# ..         ...          ...           ...             ...
# 183          0           35             0            1020
# 184          0            1             0               8
# 185          2          591             0            1320
# 186          0          333            93           14187
# 187          0          228            32            6359
#
#                          Date Premium
# 0   2020-10-06 02:49:09+00:00      {}
# 1   2020-10-06 02:49:09+00:00      {}
# 2   2020-10-06 02:49:09+00:00      {}
# 3   2020-10-06 02:49:09+00:00      {}
# 4   2020-10-06 02:49:09+00:00      {}
# ..                        ...     ...
# 183 2020-10-06 02:49:09+00:00      {}
# 184 2020-10-06 02:49:09+00:00      {}
# 185 2020-10-06 02:49:09+00:00      {}
# 186 2020-10-06 02:49:09+00:00      {}
# 187 2020-10-06 02:49:09+00:00      {}
#
# [188 rows x 11 columns]

# %%
df_country = df.set_index("Country")

# %%
df_country
# Out:
#                CountryCode            Slug  NewConfirmed  TotalConfirmed  \
# Country
# Afghanistan             AF     afghanistan            44           39341
# Albania                 AL         albania           149           14266
# Algeria                 DZ         algeria           141           52136
# Andorra                 AD         andorra             0            2110
# Angola                  AO          angola            32            5402
# ...                    ...             ...           ...             ...
# Viet Nam                VN         vietnam             0            1096
# Western Sahara          EH  western-sahara             0              10
# Yemen                   YE           yemen             0            2041
# Zambia                  ZM          zambia            78           15052
# Zimbabwe                ZW        zimbabwe             3            7888
#
#                 NewDeaths  TotalDeaths  NewRecovered  TotalRecovered  \
# Country
# Afghanistan             0         1462            10           32852
# Albania                 4          396           139            8675
# Algeria                 4         1760            96           36578
# Andorra                 0           53             0            1540
# Angola                  2          195           141            2577
# ...                   ...          ...           ...             ...
# Viet Nam                0           35             0            1020
# Western Sahara          0            1             0               8
# Yemen                   2          591             0            1320
# Zambia                  0          333            93           14187
# Zimbabwe                0          228            32            6359
#
#                                     Date Premium
# Country
# Afghanistan    2020-10-06 02:49:09+00:00      {}
# Albania        2020-10-06 02:49:09+00:00      {}
# Algeria        2020-10-06 02:49:09+00:00      {}
# Andorra        2020-10-06 02:49:09+00:00      {}
# Angola         2020-10-06 02:49:09+00:00      {}
# ...                                  ...     ...
# Viet Nam       2020-10-06 02:49:09+00:00      {}
# Western Sahara 2020-10-06 02:49:09+00:00      {}
# Yemen          2020-10-06 02:49:09+00:00      {}
# Zambia         2020-10-06 02:49:09+00:00      {}
# Zimbabwe       2020-10-06 02:49:09+00:00      {}
#
# [188 rows x 10 columns]

# %%
df_country.loc["Israel",:]
# Out:
# CountryCode                              IL
# Slug                                 israel
# NewConfirmed                           2332
# TotalConfirmed                       266775
# NewDeaths                                37
# TotalDeaths                            1719
# NewRecovered                           4378
# TotalRecovered                       195629
# Date              2020-10-06 02:49:09+00:00
# Premium                                  {}
# Name: Israel, dtype: object

# %%
response = requests.get("https://api.covid19api.com/total/country/israel")
print(response)
# Out:
# <Response [200]>

# %%
contents = json.loads(response.content)

# %%
contents
# Out:
# [{'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-01-22T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-01-23T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-01-24T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-01-25T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-01-26T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-01-27T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-01-28T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-01-29T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-01-30T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-01-31T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-02-01T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-02-02T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-02-03T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-02-04T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-02-05T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-02-06T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-02-07T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-02-08T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-02-09T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-02-10T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-02-11T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-02-12T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-02-13T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-02-14T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-02-15T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-02-16T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-02-17T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-02-18T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-02-19T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 0,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 0,
#   'Date': '2020-02-20T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 1,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 1,
#   'Date': '2020-02-21T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 1,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 1,
#   'Date': '2020-02-22T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 1,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 1,
#   'Date': '2020-02-23T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 1,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 1,
#   'Date': '2020-02-24T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 1,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 1,
#   'Date': '2020-02-25T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 2,
#   'Deaths': 0,
#   'Recovered': 0,
#   'Active': 2,
#   'Date': '2020-02-26T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 3,
#   'Deaths': 0,
#   'Recovered': 1,
#   'Active': 2,
#   'Date': '2020-02-27T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 4,
#   'Deaths': 0,
#   'Recovered': 1,
#   'Active': 3,
#   'Date': '2020-02-28T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 7,
#   'Deaths': 0,
#   'Recovered': 1,
#   'Active': 6,
#   'Date': '2020-02-29T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 10,
#   'Deaths': 0,
#   'Recovered': 1,
#   'Active': 9,
#   'Date': '2020-03-01T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 10,
#   'Deaths': 0,
#   'Recovered': 1,
#   'Active': 9,
#   'Date': '2020-03-02T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 12,
#   'Deaths': 0,
#   'Recovered': 1,
#   'Active': 11,
#   'Date': '2020-03-03T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 15,
#   'Deaths': 0,
#   'Recovered': 1,
#   'Active': 14,
#   'Date': '2020-03-04T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 20,
#   'Deaths': 0,
#   'Recovered': 1,
#   'Active': 19,
#   'Date': '2020-03-05T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 37,
#   'Deaths': 0,
#   'Recovered': 2,
#   'Active': 35,
#   'Date': '2020-03-06T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 43,
#   'Deaths': 0,
#   'Recovered': 2,
#   'Active': 41,
#   'Date': '2020-03-07T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 61,
#   'Deaths': 0,
#   'Recovered': 2,
#   'Active': 59,
#   'Date': '2020-03-08T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 61,
#   'Deaths': 0,
#   'Recovered': 2,
#   'Active': 59,
#   'Date': '2020-03-09T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 75,
#   'Deaths': 0,
#   'Recovered': 4,
#   'Active': 71,
#   'Date': '2020-03-10T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 79,
#   'Deaths': 0,
#   'Recovered': 4,
#   'Active': 75,
#   'Date': '2020-03-11T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 100,
#   'Deaths': 0,
#   'Recovered': 4,
#   'Active': 96,
#   'Date': '2020-03-12T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 126,
#   'Deaths': 0,
#   'Recovered': 4,
#   'Active': 122,
#   'Date': '2020-03-13T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 155,
#   'Deaths': 0,
#   'Recovered': 4,
#   'Active': 151,
#   'Date': '2020-03-14T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 213,
#   'Deaths': 0,
#   'Recovered': 4,
#   'Active': 209,
#   'Date': '2020-03-15T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 218,
#   'Deaths': 0,
#   'Recovered': 4,
#   'Active': 214,
#   'Date': '2020-03-16T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 250,
#   'Deaths': 0,
#   'Recovered': 11,
#   'Active': 239,
#   'Date': '2020-03-17T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 304,
#   'Deaths': 0,
#   'Recovered': 11,
#   'Active': 293,
#   'Date': '2020-03-18T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 427,
#   'Deaths': 0,
#   'Recovered': 11,
#   'Active': 416,
#   'Date': '2020-03-19T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 529,
#   'Deaths': 0,
#   'Recovered': 14,
#   'Active': 515,
#   'Date': '2020-03-20T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 712,
#   'Deaths': 1,
#   'Recovered': 36,
#   'Active': 675,
#   'Date': '2020-03-21T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 883,
#   'Deaths': 1,
#   'Recovered': 37,
#   'Active': 845,
#   'Date': '2020-03-22T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 1071,
#   'Deaths': 1,
#   'Recovered': 37,
#   'Active': 1033,
#   'Date': '2020-03-23T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 1238,
#   'Deaths': 3,
#   'Recovered': 53,
#   'Active': 1182,
#   'Date': '2020-03-24T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 2369,
#   'Deaths': 5,
#   'Recovered': 58,
#   'Active': 2306,
#   'Date': '2020-03-25T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 2693,
#   'Deaths': 8,
#   'Recovered': 68,
#   'Active': 2617,
#   'Date': '2020-03-26T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 3035,
#   'Deaths': 12,
#   'Recovered': 79,
#   'Active': 2944,
#   'Date': '2020-03-27T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 3619,
#   'Deaths': 12,
#   'Recovered': 89,
#   'Active': 3518,
#   'Date': '2020-03-28T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 4247,
#   'Deaths': 15,
#   'Recovered': 132,
#   'Active': 4100,
#   'Date': '2020-03-29T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 4695,
#   'Deaths': 16,
#   'Recovered': 161,
#   'Active': 4518,
#   'Date': '2020-03-30T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 5358,
#   'Deaths': 20,
#   'Recovered': 224,
#   'Active': 5114,
#   'Date': '2020-03-31T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 6092,
#   'Deaths': 26,
#   'Recovered': 241,
#   'Active': 5825,
#   'Date': '2020-04-01T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 6857,
#   'Deaths': 36,
#   'Recovered': 338,
#   'Active': 6483,
#   'Date': '2020-04-02T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 7428,
#   'Deaths': 40,
#   'Recovered': 403,
#   'Active': 6985,
#   'Date': '2020-04-03T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 7851,
#   'Deaths': 44,
#   'Recovered': 427,
#   'Active': 7380,
#   'Date': '2020-04-04T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 8430,
#   'Deaths': 49,
#   'Recovered': 477,
#   'Active': 7904,
#   'Date': '2020-04-05T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 8904,
#   'Deaths': 57,
#   'Recovered': 585,
#   'Active': 8262,
#   'Date': '2020-04-06T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 9248,
#   'Deaths': 65,
#   'Recovered': 770,
#   'Active': 8413,
#   'Date': '2020-04-07T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 9404,
#   'Deaths': 73,
#   'Recovered': 801,
#   'Active': 8530,
#   'Date': '2020-04-08T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 9968,
#   'Deaths': 86,
#   'Recovered': 1011,
#   'Active': 8871,
#   'Date': '2020-04-09T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 10408,
#   'Deaths': 95,
#   'Recovered': 1183,
#   'Active': 9130,
#   'Date': '2020-04-10T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 10743,
#   'Deaths': 101,
#   'Recovered': 1341,
#   'Active': 9301,
#   'Date': '2020-04-11T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 11145,
#   'Deaths': 103,
#   'Recovered': 1627,
#   'Active': 9415,
#   'Date': '2020-04-12T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 11586,
#   'Deaths': 116,
#   'Recovered': 1855,
#   'Active': 9615,
#   'Date': '2020-04-13T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 12046,
#   'Deaths': 123,
#   'Recovered': 2195,
#   'Active': 9728,
#   'Date': '2020-04-14T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 12501,
#   'Deaths': 130,
#   'Recovered': 2563,
#   'Active': 9808,
#   'Date': '2020-04-15T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 12758,
#   'Deaths': 142,
#   'Recovered': 2818,
#   'Active': 9798,
#   'Date': '2020-04-16T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 12982,
#   'Deaths': 151,
#   'Recovered': 3126,
#   'Active': 9705,
#   'Date': '2020-04-17T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 13265,
#   'Deaths': 164,
#   'Recovered': 3456,
#   'Active': 9645,
#   'Date': '2020-04-18T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 13491,
#   'Deaths': 172,
#   'Recovered': 3754,
#   'Active': 9565,
#   'Date': '2020-04-19T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 13713,
#   'Deaths': 177,
#   'Recovered': 4049,
#   'Active': 9487,
#   'Date': '2020-04-20T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 13942,
#   'Deaths': 184,
#   'Recovered': 4507,
#   'Active': 9251,
#   'Date': '2020-04-21T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 14498,
#   'Deaths': 189,
#   'Recovered': 5215,
#   'Active': 9094,
#   'Date': '2020-04-22T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 14803,
#   'Deaths': 192,
#   'Recovered': 5611,
#   'Active': 9000,
#   'Date': '2020-04-23T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 15058,
#   'Deaths': 194,
#   'Recovered': 6003,
#   'Active': 8861,
#   'Date': '2020-04-24T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 15298,
#   'Deaths': 199,
#   'Recovered': 6435,
#   'Active': 8664,
#   'Date': '2020-04-25T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 15443,
#   'Deaths': 201,
#   'Recovered': 6731,
#   'Active': 8511,
#   'Date': '2020-04-26T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 15555,
#   'Deaths': 204,
#   'Recovered': 7200,
#   'Active': 8151,
#   'Date': '2020-04-27T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 15728,
#   'Deaths': 210,
#   'Recovered': 7746,
#   'Active': 7772,
#   'Date': '2020-04-28T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 15834,
#   'Deaths': 215,
#   'Recovered': 8233,
#   'Active': 7386,
#   'Date': '2020-04-29T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 15946,
#   'Deaths': 222,
#   'Recovered': 8561,
#   'Active': 7163,
#   'Date': '2020-04-30T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 16101,
#   'Deaths': 225,
#   'Recovered': 9156,
#   'Active': 6720,
#   'Date': '2020-05-01T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 16185,
#   'Deaths': 229,
#   'Recovered': 9593,
#   'Active': 6363,
#   'Date': '2020-05-02T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 16208,
#   'Deaths': 232,
#   'Recovered': 9749,
#   'Active': 6227,
#   'Date': '2020-05-03T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 16246,
#   'Deaths': 235,
#   'Recovered': 10064,
#   'Active': 5947,
#   'Date': '2020-05-04T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 16289,
#   'Deaths': 238,
#   'Recovered': 10465,
#   'Active': 5586,
#   'Date': '2020-05-05T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 16310,
#   'Deaths': 239,
#   'Recovered': 10637,
#   'Active': 5434,
#   'Date': '2020-05-06T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 16381,
#   'Deaths': 240,
#   'Recovered': 10873,
#   'Active': 5268,
#   'Date': '2020-05-07T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 16436,
#   'Deaths': 245,
#   'Recovered': 11229,
#   'Active': 4962,
#   'Date': '2020-05-08T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 16454,
#   'Deaths': 247,
#   'Recovered': 11376,
#   'Active': 4831,
#   'Date': '2020-05-09T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 16477,
#   'Deaths': 252,
#   'Recovered': 11430,
#   'Active': 4795,
#   'Date': '2020-05-10T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 16506,
#   'Deaths': 258,
#   'Recovered': 11843,
#   'Active': 4405,
#   'Date': '2020-05-11T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 16529,
#   'Deaths': 260,
#   'Recovered': 12083,
#   'Active': 4186,
#   'Date': '2020-05-12T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 16548,
#   'Deaths': 264,
#   'Recovered': 12232,
#   'Active': 4052,
#   'Date': '2020-05-13T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 16579,
#   'Deaths': 265,
#   'Recovered': 12521,
#   'Active': 3793,
#   'Date': '2020-05-14T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 16589,
#   'Deaths': 266,
#   'Recovered': 12587,
#   'Active': 3736,
#   'Date': '2020-05-15T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 16608,
#   'Deaths': 268,
#   'Recovered': 12855,
#   'Active': 3485,
#   'Date': '2020-05-16T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 16617,
#   'Deaths': 272,
#   'Recovered': 12942,
#   'Active': 3403,
#   'Date': '2020-05-17T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 16643,
#   'Deaths': 276,
#   'Recovered': 13253,
#   'Active': 3114,
#   'Date': '2020-05-18T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 16659,
#   'Deaths': 278,
#   'Recovered': 13435,
#   'Active': 2946,
#   'Date': '2020-05-19T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 16667,
#   'Deaths': 279,
#   'Recovered': 13504,
#   'Active': 2884,
#   'Date': '2020-05-20T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 16683,
#   'Deaths': 279,
#   'Recovered': 13724,
#   'Active': 2680,
#   'Date': '2020-05-21T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 16690,
#   'Deaths': 279,
#   'Recovered': 13915,
#   'Active': 2496,
#   'Date': '2020-05-22T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 16712,
#   'Deaths': 279,
#   'Recovered': 14090,
#   'Active': 2343,
#   'Date': '2020-05-23T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 16717,
#   'Deaths': 279,
#   'Recovered': 14153,
#   'Active': 2285,
#   'Date': '2020-05-24T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 16734,
#   'Deaths': 281,
#   'Recovered': 14307,
#   'Active': 2146,
#   'Date': '2020-05-25T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 16757,
#   'Deaths': 281,
#   'Recovered': 14457,
#   'Active': 2019,
#   'Date': '2020-05-26T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 16793,
#   'Deaths': 281,
#   'Recovered': 14570,
#   'Active': 1942,
#   'Date': '2020-05-27T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 16872,
#   'Deaths': 284,
#   'Recovered': 14679,
#   'Active': 1909,
#   'Date': '2020-05-28T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 16987,
#   'Deaths': 284,
#   'Recovered': 14776,
#   'Active': 1927,
#   'Date': '2020-05-29T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 17012,
#   'Deaths': 284,
#   'Recovered': 14811,
#   'Active': 1917,
#   'Date': '2020-05-30T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 17071,
#   'Deaths': 285,
#   'Recovered': 14812,
#   'Active': 1974,
#   'Date': '2020-05-31T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 17169,
#   'Deaths': 285,
#   'Recovered': 14878,
#   'Active': 2006,
#   'Date': '2020-06-01T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 17285,
#   'Deaths': 290,
#   'Recovered': 14940,
#   'Active': 2055,
#   'Date': '2020-06-02T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 17377,
#   'Deaths': 291,
#   'Recovered': 14983,
#   'Active': 2103,
#   'Date': '2020-06-03T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 17495,
#   'Deaths': 291,
#   'Recovered': 15013,
#   'Active': 2191,
#   'Date': '2020-06-04T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 17562,
#   'Deaths': 291,
#   'Recovered': 15026,
#   'Active': 2245,
#   'Date': '2020-06-05T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 17752,
#   'Deaths': 295,
#   'Recovered': 15042,
#   'Active': 2415,
#   'Date': '2020-06-06T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 17863,
#   'Deaths': 298,
#   'Recovered': 15091,
#   'Active': 2474,
#   'Date': '2020-06-07T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 18032,
#   'Deaths': 298,
#   'Recovered': 15102,
#   'Active': 2632,
#   'Date': '2020-06-08T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 18180,
#   'Deaths': 299,
#   'Recovered': 15159,
#   'Active': 2722,
#   'Date': '2020-06-09T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 18355,
#   'Deaths': 299,
#   'Recovered': 15168,
#   'Active': 2888,
#   'Date': '2020-06-10T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 18569,
#   'Deaths': 300,
#   'Recovered': 15250,
#   'Active': 3019,
#   'Date': '2020-06-11T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 18795,
#   'Deaths': 300,
#   'Recovered': 15288,
#   'Active': 3207,
#   'Date': '2020-06-12T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 18972,
#   'Deaths': 300,
#   'Recovered': 15357,
#   'Active': 3315,
#   'Date': '2020-06-13T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 19055,
#   'Deaths': 300,
#   'Recovered': 15375,
#   'Active': 3380,
#   'Date': '2020-06-14T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 19237,
#   'Deaths': 302,
#   'Recovered': 15415,
#   'Active': 3520,
#   'Date': '2020-06-15T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 19495,
#   'Deaths': 302,
#   'Recovered': 15449,
#   'Active': 3744,
#   'Date': '2020-06-16T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 19783,
#   'Deaths': 303,
#   'Recovered': 15459,
#   'Active': 4021,
#   'Date': '2020-06-17T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 20036,
#   'Deaths': 303,
#   'Recovered': 15518,
#   'Active': 4215,
#   'Date': '2020-06-18T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 20339,
#   'Deaths': 304,
#   'Recovered': 15586,
#   'Active': 4449,
#   'Date': '2020-06-19T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 20633,
#   'Deaths': 305,
#   'Recovered': 15586,
#   'Active': 4742,
#   'Date': '2020-06-20T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 20778,
#   'Deaths': 306,
#   'Recovered': 15694,
#   'Active': 4778,
#   'Date': '2020-06-21T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 21082,
#   'Deaths': 307,
#   'Recovered': 15761,
#   'Active': 5014,
#   'Date': '2020-06-22T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 21512,
#   'Deaths': 308,
#   'Recovered': 15869,
#   'Active': 5335,
#   'Date': '2020-06-23T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 22044,
#   'Deaths': 308,
#   'Recovered': 15940,
#   'Active': 5796,
#   'Date': '2020-06-24T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 22400,
#   'Deaths': 309,
#   'Recovered': 16007,
#   'Active': 6084,
#   'Date': '2020-06-25T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 22800,
#   'Deaths': 314,
#   'Recovered': 16872,
#   'Active': 5614,
#   'Date': '2020-06-26T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 23421,
#   'Deaths': 317,
#   'Recovered': 17002,
#   'Active': 6102,
#   'Date': '2020-06-27T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 23755,
#   'Deaths': 318,
#   'Recovered': 17074,
#   'Active': 6363,
#   'Date': '2020-06-28T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 24441,
#   'Deaths': 319,
#   'Recovered': 17218,
#   'Active': 6904,
#   'Date': '2020-06-29T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 25244,
#   'Deaths': 320,
#   'Recovered': 17341,
#   'Active': 7583,
#   'Date': '2020-06-30T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 26257,
#   'Deaths': 322,
#   'Recovered': 17452,
#   'Active': 8483,
#   'Date': '2020-07-01T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 27047,
#   'Deaths': 324,
#   'Recovered': 17547,
#   'Active': 9176,
#   'Date': '2020-07-02T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 28055,
#   'Deaths': 326,
#   'Recovered': 17669,
#   'Active': 10060,
#   'Date': '2020-07-03T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 29170,
#   'Deaths': 330,
#   'Recovered': 17816,
#   'Active': 11024,
#   'Date': '2020-07-04T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 29958,
#   'Deaths': 331,
#   'Recovered': 17950,
#   'Active': 11677,
#   'Date': '2020-07-05T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 30749,
#   'Deaths': 334,
#   'Recovered': 18056,
#   'Active': 12359,
#   'Date': '2020-07-06T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 32222,
#   'Deaths': 342,
#   'Recovered': 18227,
#   'Active': 13653,
#   'Date': '2020-07-07T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 33557,
#   'Deaths': 344,
#   'Recovered': 18338,
#   'Active': 14875,
#   'Date': '2020-07-08T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 34825,
#   'Deaths': 348,
#   'Recovered': 18452,
#   'Active': 16025,
#   'Date': '2020-07-09T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 36266,
#   'Deaths': 351,
#   'Recovered': 18613,
#   'Active': 17302,
#   'Date': '2020-07-10T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 37464,
#   'Deaths': 354,
#   'Recovered': 18814,
#   'Active': 18296,
#   'Date': '2020-07-11T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 38670,
#   'Deaths': 362,
#   'Recovered': 19008,
#   'Active': 19300,
#   'Date': '2020-07-12T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 40632,
#   'Deaths': 365,
#   'Recovered': 19395,
#   'Active': 20872,
#   'Date': '2020-07-13T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 42360,
#   'Deaths': 371,
#   'Recovered': 19665,
#   'Active': 22324,
#   'Date': '2020-07-14T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 44188,
#   'Deaths': 376,
#   'Recovered': 19989,
#   'Active': 23823,
#   'Date': '2020-07-15T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 46059,
#   'Deaths': 384,
#   'Recovered': 20370,
#   'Active': 25305,
#   'Date': '2020-07-16T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 47459,
#   'Deaths': 392,
#   'Recovered': 20744,
#   'Active': 26323,
#   'Date': '2020-07-17T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 49365,
#   'Deaths': 401,
#   'Recovered': 21348,
#   'Active': 27616,
#   'Date': '2020-07-18T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 50289,
#   'Deaths': 409,
#   'Recovered': 21675,
#   'Active': 28205,
#   'Date': '2020-07-19T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 52003,
#   'Deaths': 415,
#   'Recovered': 22154,
#   'Active': 29434,
#   'Date': '2020-07-20T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 54042,
#   'Deaths': 425,
#   'Recovered': 22743,
#   'Active': 30874,
#   'Date': '2020-07-21T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 56085,
#   'Deaths': 430,
#   'Recovered': 23310,
#   'Active': 32345,
#   'Date': '2020-07-22T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 57982,
#   'Deaths': 442,
#   'Recovered': 24044,
#   'Active': 33496,
#   'Date': '2020-07-23T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 59475,
#   'Deaths': 448,
#   'Recovered': 26797,
#   'Active': 32230,
#   'Date': '2020-07-24T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 60678,
#   'Deaths': 457,
#   'Recovered': 26917,
#   'Active': 33304,
#   'Date': '2020-07-25T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 61956,
#   'Deaths': 470,
#   'Recovered': 27025,
#   'Active': 34461,
#   'Date': '2020-07-26T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 63985,
#   'Deaths': 474,
#   'Recovered': 27133,
#   'Active': 36378,
#   'Date': '2020-07-27T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 66293,
#   'Deaths': 486,
#   'Recovered': 32182,
#   'Active': 33625,
#   'Date': '2020-07-28T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 68299,
#   'Deaths': 491,
#   'Recovered': 32746,
#   'Active': 35062,
#   'Date': '2020-07-29T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 70036,
#   'Deaths': 500,
#   'Recovered': 43489,
#   'Active': 26047,
#   'Date': '2020-07-30T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 70970,
#   'Deaths': 512,
#   'Recovered': 43850,
#   'Active': 26608,
#   'Date': '2020-07-31T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 72218,
#   'Deaths': 526,
#   'Recovered': 45102,
#   'Active': 26590,
#   'Date': '2020-08-01T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 72815,
#   'Deaths': 536,
#   'Recovered': 45677,
#   'Active': 26602,
#   'Date': '2020-08-02T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 74430,
#   'Deaths': 546,
#   'Recovered': 47571,
#   'Active': 26313,
#   'Date': '2020-08-03T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 76198,
#   'Deaths': 561,
#   'Recovered': 49834,
#   'Active': 25803,
#   'Date': '2020-08-04T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 77919,
#   'Deaths': 565,
#   'Recovered': 51395,
#   'Active': 25959,
#   'Date': '2020-08-05T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 79559,
#   'Deaths': 576,
#   'Recovered': 53427,
#   'Active': 25556,
#   'Date': '2020-08-06T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 80991,
#   'Deaths': 581,
#   'Recovered': 55313,
#   'Active': 25097,
#   'Date': '2020-08-07T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 82324,
#   'Deaths': 593,
#   'Recovered': 57071,
#   'Active': 24660,
#   'Date': '2020-08-08T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 83002,
#   'Deaths': 600,
#   'Recovered': 57533,
#   'Active': 24869,
#   'Date': '2020-08-09T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 84722,
#   'Deaths': 613,
#   'Recovered': 58998,
#   'Active': 25111,
#   'Date': '2020-08-10T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 86593,
#   'Deaths': 622,
#   'Recovered': 60080,
#   'Active': 25891,
#   'Date': '2020-08-11T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 88151,
#   'Deaths': 639,
#   'Recovered': 62109,
#   'Active': 25403,
#   'Date': '2020-08-12T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 89822,
#   'Deaths': 651,
#   'Recovered': 64746,
#   'Active': 24425,
#   'Date': '2020-08-13T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 91080,
#   'Deaths': 665,
#   'Recovered': 66965,
#   'Active': 23450,
#   'Date': '2020-08-14T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 92233,
#   'Deaths': 674,
#   'Recovered': 67950,
#   'Active': 23609,
#   'Date': '2020-08-15T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 92680,
#   'Deaths': 685,
#   'Recovered': 68510,
#   'Active': 23485,
#   'Date': '2020-08-16T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 94751,
#   'Deaths': 692,
#   'Recovered': 70291,
#   'Active': 23768,
#   'Date': '2020-08-17T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 96409,
#   'Deaths': 708,
#   'Recovered': 71990,
#   'Active': 23711,
#   'Date': '2020-08-18T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 97969,
#   'Deaths': 781,
#   'Recovered': 73092,
#   'Active': 24096,
#   'Date': '2020-08-19T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 99599,
#   'Deaths': 795,
#   'Recovered': 74579,
#   'Active': 24225,
#   'Date': '2020-08-20T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 100716,
#   'Deaths': 809,
#   'Recovered': 77785,
#   'Active': 22122,
#   'Date': '2020-08-21T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 101933,
#   'Deaths': 819,
#   'Recovered': 78651,
#   'Active': 22463,
#   'Date': '2020-08-22T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 102663,
#   'Deaths': 834,
#   'Recovered': 79514,
#   'Active': 22315,
#   'Date': '2020-08-23T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 104472,
#   'Deaths': 847,
#   'Recovered': 81642,
#   'Active': 21983,
#   'Date': '2020-08-24T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 106460,
#   'Deaths': 859,
#   'Recovered': 83822,
#   'Active': 21779,
#   'Date': '2020-08-25T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 108403,
#   'Deaths': 875,
#   'Recovered': 86466,
#   'Active': 21062,
#   'Date': '2020-08-26T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 110403,
#   'Deaths': 884,
#   'Recovered': 87726,
#   'Active': 21793,
#   'Date': '2020-08-27T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 112000,
#   'Deaths': 894,
#   'Recovered': 91051,
#   'Active': 20055,
#   'Date': '2020-08-28T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 113465,
#   'Deaths': 906,
#   'Recovered': 92104,
#   'Active': 20455,
#   'Date': '2020-08-29T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 114020,
#   'Deaths': 919,
#   'Recovered': 92796,
#   'Active': 20305,
#   'Date': '2020-08-30T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 116596,
#   'Deaths': 939,
#   'Recovered': 95009,
#   'Active': 20648,
#   'Date': '2020-08-31T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 118538,
#   'Deaths': 957,
#   'Recovered': 96214,
#   'Active': 21367,
#   'Date': '2020-09-01T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 121464,
#   'Deaths': 969,
#   'Recovered': 97234,
#   'Active': 23261,
#   'Date': '2020-09-02T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 124455,
#   'Deaths': 985,
#   'Recovered': 98645,
#   'Active': 24825,
#   'Date': '2020-09-03T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 126419,
#   'Deaths': 993,
#   'Recovered': 100357,
#   'Active': 25069,
#   'Date': '2020-09-04T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 128936,
#   'Deaths': 1007,
#   'Recovered': 101481,
#   'Active': 26448,
#   'Date': '2020-09-05T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 130644,
#   'Deaths': 1019,
#   'Recovered': 102477,
#   'Active': 27148,
#   'Date': '2020-09-06T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 133975,
#   'Deaths': 1026,
#   'Recovered': 105455,
#   'Active': 27494,
#   'Date': '2020-09-07T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 137565,
#   'Deaths': 1040,
#   'Recovered': 107003,
#   'Active': 29522,
#   'Date': '2020-09-08T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 141097,
#   'Deaths': 1054,
#   'Recovered': 108354,
#   'Active': 31689,
#   'Date': '2020-09-09T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 145526,
#   'Deaths': 1077,
#   'Recovered': 109942,
#   'Active': 34507,
#   'Date': '2020-09-10T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 148564,
#   'Deaths': 1090,
#   'Recovered': 111728,
#   'Active': 35746,
#   'Date': '2020-09-11T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 152722,
#   'Deaths': 1103,
#   'Recovered': 113496,
#   'Active': 38123,
#   'Date': '2020-09-12T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 155604,
#   'Deaths': 1119,
#   'Recovered': 114998,
#   'Active': 39487,
#   'Date': '2020-09-13T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 160368,
#   'Deaths': 1136,
#   'Recovered': 118570,
#   'Active': 40662,
#   'Date': '2020-09-14T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 164402,
#   'Deaths': 1147,
#   'Recovered': 120727,
#   'Active': 42528,
#   'Date': '2020-09-15T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 170465,
#   'Deaths': 1165,
#   'Recovered': 123219,
#   'Active': 46081,
#   'Date': '2020-09-16T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 175256,
#   'Deaths': 1169,
#   'Recovered': 126329,
#   'Active': 47758,
#   'Date': '2020-09-17T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 179071,
#   'Deaths': 1196,
#   'Recovered': 130024,
#   'Active': 47851,
#   'Date': '2020-09-18T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 183602,
#   'Deaths': 1226,
#   'Recovered': 132449,
#   'Active': 49927,
#   'Date': '2020-09-19T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 187902,
#   'Deaths': 1256,
#   'Recovered': 134069,
#   'Active': 52577,
#   'Date': '2020-09-20T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 190929,
#   'Deaths': 1273,
#   'Recovered': 136780,
#   'Active': 52876,
#   'Date': '2020-09-21T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 193374,
#   'Deaths': 1285,
#   'Recovered': 140751,
#   'Active': 51338,
#   'Date': '2020-09-22T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 204690,
#   'Deaths': 1325,
#   'Recovered': 144963,
#   'Active': 58402,
#   'Date': '2020-09-23T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 212115,
#   'Deaths': 1378,
#   'Recovered': 148813,
#   'Active': 61924,
#   'Date': '2020-09-24T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 217899,
#   'Deaths': 1412,
#   'Recovered': 153574,
#   'Active': 62913,
#   'Date': '2020-09-25T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 227100,
#   'Deaths': 1441,
#   'Recovered': 157537,
#   'Active': 68122,
#   'Date': '2020-09-26T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 231026,
#   'Deaths': 1466,
#   'Recovered': 159931,
#   'Active': 69629,
#   'Date': '2020-09-27T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 233265,
#   'Deaths': 1507,
#   'Recovered': 165191,
#   'Active': 66567,
#   'Date': '2020-09-28T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 236926,
#   'Deaths': 1528,
#   'Recovered': 167804,
#   'Active': 67594,
#   'Date': '2020-09-29T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 245494,
#   'Deaths': 1569,
#   'Recovered': 174506,
#   'Active': 69419,
#   'Date': '2020-09-30T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 253490,
#   'Deaths': 1622,
#   'Recovered': 179468,
#   'Active': 72400,
#   'Date': '2020-10-01T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 258920,
#   'Deaths': 1633,
#   'Recovered': 185122,
#   'Active': 72165,
#   'Date': '2020-10-02T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 264443,
#   'Deaths': 1682,
#   'Recovered': 191251,
#   'Active': 71510,
#   'Date': '2020-10-03T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 266775,
#   'Deaths': 1719,
#   'Recovered': 195629,
#   'Active': 69427,
#   'Date': '2020-10-04T00:00:00Z'},
#  {'Country': 'Israel',
#   'CountryCode': '',
#   'Province': '',
#   'City': '',
#   'CityCode': '',
#   'Lat': '0',
#   'Lon': '0',
#   'Confirmed': 272309,
#   'Deaths': 1757,
#   'Recovered': 204355,
#   'Active': 66197,
#   'Date': '2020-10-05T00:00:00Z'}]

# %%
df_israel = pd.read_json(response.content)

# %%
df_israel
# Out:
#     Country CountryCode Province City CityCode  Lat  Lon  Confirmed  Deaths  \
# 0    Israel                                       0    0          0       0
# 1    Israel                                       0    0          0       0
# 2    Israel                                       0    0          0       0
# 3    Israel                                       0    0          0       0
# 4    Israel                                       0    0          0       0
# ..      ...         ...      ...  ...      ...  ...  ...        ...     ...
# 253  Israel                                       0    0     253490    1622
# 254  Israel                                       0    0     258920    1633
# 255  Israel                                       0    0     264443    1682
# 256  Israel                                       0    0     266775    1719
# 257  Israel                                       0    0     272309    1757
#
#      Recovered  Active                      Date
# 0            0       0 2020-01-22 00:00:00+00:00
# 1            0       0 2020-01-23 00:00:00+00:00
# 2            0       0 2020-01-24 00:00:00+00:00
# 3            0       0 2020-01-25 00:00:00+00:00
# 4            0       0 2020-01-26 00:00:00+00:00
# ..         ...     ...                       ...
# 253     179468   72400 2020-10-01 00:00:00+00:00
# 254     185122   72165 2020-10-02 00:00:00+00:00
# 255     191251   71510 2020-10-03 00:00:00+00:00
# 256     195629   69427 2020-10-04 00:00:00+00:00
# 257     204355   66197 2020-10-05 00:00:00+00:00
#
# [258 rows x 12 columns]

# %%
conf = df_israel.loc[:,"Confirmed"]
np.size(conf)
# Out:
# 258

# %%
plt.plot(conf)
